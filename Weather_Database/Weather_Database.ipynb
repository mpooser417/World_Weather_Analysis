#  (-75.82227350804743, 125.51511601081995),
#  (-82.90468813179687, -104.23968112088525),
#  (-47.48454828494177, 73.99628090580114),
#  (-1.5744925392876894, 33.096761617837956),
#  (-58.5506290549138, 90.82328277357738),
#  (34.121355981649344, 73.61444764079863),
#  (-14.412030946670157, -159.77311051163525),
#  (70.20916709806477, 1.4501362270601703),
#  (45.700948123358216, -101.3776961181237),
#  (-17.925373374071512, -169.24707901243846),
#  ...]

# %%
from citipy import citipy

# %%
#Get the nearest city using citipy
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
        
cities
# Out:
# ['hualmay',
#  'chokurdakh',
#  'xinqing',
#  'vardo',
#  'rikitea',
#  'hermanus',
#  'kodiak',
#  'kamenskoye',
#  'bredasdorp',
#  'ponta do sol',
#  'mataura',
#  'tuktoyaktuk',
#  'pitimbu',
#  'ilinskiy',
#  'busselton',
#  'barra do corda',
#  'nortelandia',
#  'port elizabeth',
#  'bethel',
#  'burica',
#  'talnakh',
#  'cape town',
#  'aklavik',
#  'avarua',
#  'necochea',
#  'uxbridge',
#  'punta arenas',
#  'port alfred',
#  'cap malheureux',
#  'cabildo',
#  'half moon bay',
#  'port-cartier',
#  'yellowknife',
#  'mawlaik',
#  'barentsburg',
#  'salmon creek',
#  'el jicaro',
#  'attawapiskat',
#  'pacific grove',
#  'ushuaia',
#  'vaini',
#  'asau',
#  'kargil',
#  'kruisfontein',
#  'hakodate',
#  'arraial do cabo',
#  'albany',
#  'kalemie',
#  'hilo',
#  'port macquarie',
#  'isilkul',
#  'leningradskiy',
#  'jamestown',
#  'safakulevo',
#  'huercal-overa',
#  'provideniya',
#  'palabuhanratu',
#  'tasiilaq',
#  'taber',
#  'salvador',
#  'porto empedocle',
#  'cabo rojo',
#  'krasnoselkup',
#  'georgetown',
#  'zhaoyuan',
#  'nizhneyansk',
#  'barrow',
#  'rio grande',
#  'ribeira grande',
#  'saint-philippe',
#  'castro',
#  'cherskiy',
#  'qaanaaq',
#  'acarau',
#  'vila franca do campo',
#  'olean',
#  'atuona',
#  'saleaula',
#  'quesnel',
#  'bilibino',
#  'morant bay',
#  'deputatskiy',
#  'naze',
#  'springdale',
#  'tuatapere',
#  'marawi',
#  'victoria',
#  'boda',
#  'ponta delgada',
#  'sinnamary',
#  'east london',
#  'hasaki',
#  'mahebourg',
#  'sao filipe',
#  'kaputa',
#  'upernavik',
#  'porto santo',
#  'hun',
#  'mahadday weyne',
#  'garowe',
#  'nchelenge',
#  'torbay',
#  'udachnyy',
#  'hobart',
#  'grindavik',
#  'saskylakh',
#  'semey',
#  'lucea',
#  'luderitz',
#  'codrington',
#  'dukat',
#  'bowen',
#  'dingle',
#  'shelburne',
#  'ngukurr',
#  'new norfolk',
#  'beringovskiy',
#  'mineiros',
#  'faanui',
#  'butaritari',
#  'sambava',
#  'lawrenceburg',
#  'lamar',
#  'thinadhoo',
#  'general roca',
#  'thompson',
#  'san benito',
#  'przhevalskoye',
#  'yulara',
#  'puerto ayora',
#  'taolanaro',
#  'cidreira',
#  'kungurtug',
#  'khatanga',
#  'broome',
#  'bluff',
#  'bondo',
#  'ilulissat',
#  'virden',
#  'kapaa',
#  'kimbe',
#  'maragogi',
#  'belushya guba',
#  'vaitupu',
#  'marsa matruh',
#  'sentyabrskiy',
#  'ballina',
#  'tutoia',
#  'namibe',
#  'los llanos de aridane',
#  'adrar',
#  'sitka',
#  'alice town',
#  'cravo norte',
#  'praia da vitoria',
#  'camopi',
#  'jarjis',
#  'ahipara',
#  'port hedland',
#  'amderma',
#  'priargunsk',
#  'pangnirtung',
#  'yanchukan',
#  'constitucion',
#  'qaqortoq',
#  'kaeo',
#  'dongsheng',
#  'umm kaddadah',
#  'barinas',
#  'olafsvik',
#  'uarini',
#  'rockport',
#  'lagoa',
#  'berlevag',
#  'fortuna',
#  'rawson',
#  'kahului',
#  'muros',
#  'illoqqortoormiut',
#  'lyngdal',
#  'pevek',
#  'price',
#  'bubaque',
#  'vao',
#  'santa rosa',
#  'dikson',
#  'bandarbeyla',
#  'ucluelet',
#  'champerico',
#  'hithadhoo',
#  'nguiu',
#  'mudyuga',
#  'meulaboh',
#  'beian',
#  'shaunavon',
#  'colomi',
#  'harwich',
#  'atasu',
#  'killybegs',
#  'ossora',
#  'havoysund',
#  'flinders',
#  'iskateley',
#  'inirida',
#  'lere',
#  'chuy',
#  'japura',
#  'verkhnevilyuysk',
#  'ambon',
#  'sao joao da barra',
#  'la candelaria',
#  'norman wells',
#  'bourail',
#  'mar del plata',
#  'byron bay',
#  'vuktyl',
#  'pisco',
#  'nanfeng',
#  'teya',
#  'zhanaozen',
#  'cabo san lucas',
#  'sola',
#  'souillac',
#  'maghama',
#  'beloha',
#  'cockburn town',
#  'polunochnoye',
#  'caravelas',
#  'buxtehude',
#  'antofagasta',
#  'narsaq',
#  'pundaguitan',
#  'hamilton',
#  'kirovskiy',
#  'tautira',
#  'lorengau',
#  'louisbourg',
#  'okato',
#  'pokaran',
#  'si sa ket',
#  'ijaki',
#  'katsuura',
#  'lar',
#  'amara',
#  'saint-pierre',
#  'kidal',
#  'bani',
#  'iqaluit',
#  'dicabisagan',
#  'tatarskaya pishlya',
#  'pechenga',
#  'kormilovka',
#  'port-gentil',
#  'zunyi',
#  'brae',
#  'ponnani',
#  'severo-kurilsk',
#  'ejura',
#  'cabra',
#  'college',
#  'progreso',
#  'labuhan',
#  'clyde river',
#  'bengkulu',
#  'vestmannaeyjar',
#  'akhtanizovskaya',
#  'yashkino',
#  'kieta',
#  'ukiah',
#  'isangel',
#  'nador',
#  'yanan',
#  'shenjiamen',
#  'christchurch',
#  'buckingham',
#  'raichur',
#  'kashi',
#  'carnarvon',
#  'port augusta',
#  'henties bay',
#  'dawson creek',
#  'portland',
#  'faya',
#  'barbar',
#  'salalah',
#  'ozgon',
#  'tsihombe',
#  'yumen',
#  'newport beach',
#  'nizhnyaya tavda',
#  'coos bay',
#  'labytnangi',
#  'jiaohe',
#  'nishihara',
#  'padang',
#  'kindu',
#  'bambous virieux',
#  'elko',
#  'bangui',
#  'rafaela',
#  'vanimo',
#  'haines junction',
#  'gallipoli',
#  'saint-francois',
#  'esperance',
#  'honningsvag',
#  'muyezerskiy',
#  'horsham',
#  'lantawan',
#  'northam',
#  'kaitangata',
#  'constanta',
#  'trofors',
#  'utmanzai',
#  'airai',
#  'porto novo',
#  'yerbogachen',
#  'tarudant',
#  'san patricio',
#  'sagopshi',
#  'dijkot',
#  'merauke',
#  'aksarka',
#  'sandwick',
#  'cuxhaven',
#  'fengkou',
#  'vaitape',
#  'sao gabriel da cachoeira',
#  'usinsk',
#  'grand-lahou',
#  'chake chake',
#  'chippewa falls',
#  'micomeseng',
#  'nikolskoye',
#  'calvillo',
#  'basco',
#  'geraldton',
#  'staveley',
#  'uyemskiy',
#  'magdagachi',
#  'te anau',
#  'the valley',
#  'togur',
#  'namatanai',
#  'opuwo',
#  'bay roberts',
#  'saldanha',
#  'powell',
#  'mareeba',
#  'longlac',
#  'ulladulla',
#  'umzimvubu',
#  'saint george',
#  'viedma',
#  'san jeronimo',
#  'freeport',
#  'saint-michel-des-saints',
#  'voznesenye',
#  'mandalgovi',
#  'longyearbyen',
#  'moose factory',
#  'aborlan',
#  'tiksi',
#  'tadine',
#  'tenenkou',
#  'karaul',
#  'mecca',
#  'alofi',
#  'rovaniemi',
#  'redmond',
#  'asfi',
#  'pangoa',
#  'olinda',
#  'grand river south east',
#  'saint-georges',
#  'ramgarh',
#  'san vicente',
#  'staromyshastovskaya',
#  'monrovia',
#  'la trinidad',
#  'ryotsu',
#  'verkhnyaya inta',
#  'san jose',
#  'acapulco',
#  'presidente venceslau',
#  'pak phanang',
#  'coahuayana',
#  'elliot lake',
#  'xixiang',
#  'saint-augustin',
#  'tazovskiy',
#  'cayenne',
#  'ixtapa',
#  'komsomolskiy',
#  'chuguyevka',
#  'volnovakha',
#  'sibu',
#  'luwuk',
#  'sol-iletsk',
#  'karauzyak',
#  'port hardy',
#  'dunedin',
#  'mariental',
#  'korla',
#  'leh',
#  'phaltan',
#  'aflu',
#  'smoky lake',
#  'weihai',
#  'mittweida',
#  'sumenep',
#  'warwick',
#  'sorvag',
#  'geresk',
#  'balikpapan',
#  'soyo',
#  'lasa',
#  'lebu',
#  'hervey bay',
#  'turbana',
#  'san quintin',
#  'lebanon',
#  'burnie',
#  'itoman',
#  'ust-nera',
#  'suruc',
#  'rabo de peixe',
#  'agadez',
#  'sobolevo',
#  'bara',
#  'fort nelson',
#  'dali',
#  'reyes',
#  'barberton',
#  'nome',
#  'old road',
#  'toliary',
#  'ortakoy',
#  'kirensk',
#  'dandong',
#  'mersing',
#  'poum',
#  'hokitika',
#  'high rock',
#  'kalmunai',
#  'nabire',
#  'tiznit',
#  'lampang',
#  'lindi',
#  'madisonville',
#  'sorong',
#  'minab',
#  'san juan de abajo',
#  'eureka',
#  'erenhot',
#  'huarmey',
#  'aswan',
#  'paramonga',
#  'birin',
#  'ostrovnoy',
#  'rawannawi',
#  'wulanhaote',
#  'onega',
#  'mount isa',
#  'shiyan',
#  'palmer',
#  'san mateo del mar',
#  'camacha',
#  'muriti',
#  'muzaffarabad',
#  'roald',
#  'mandan',
#  'presidencia roque saenz pena',
#  'porgera',
#  'gua musang',
#  'bafq',
#  'bolungarvik',
#  'acacoyagua',
#  'inuvik',
#  'valparaiso',
#  'waddan',
#  'kununurra',
#  'beyneu',
#  'nanortalik',
#  'kulhudhuffushi',
#  'pandan',
#  'barentu',
#  'eura',
#  'alice springs',
#  'orcopampa',
#  'jardim',
#  'mys shmidta',
#  'primorsko',
#  'mackay',
#  'mattru',
#  'ust-ilimsk',
#  'evensk',
#  'wenatchee',
#  'fort abbas',
#  'moron',
#  'guerrero negro',
#  'toora-khem',
#  'kavieng',
#  'pavlodar',
#  'rumford',
#  'bay city',
#  'robertsport',
#  'votkinsk',
#  'xining',
#  'imbituba',
#  'leninskoye',
#  'maningrida',
#  'avera',
#  'bukene',
#  'manokwari',
#  'cordoba',
#  'batangafo',
#  'benghazi',
#  'iralaya',
#  'tanout',
#  'ongandjera',
#  'tilichiki',
#  'ternate',
#  'lolua',
#  'chamba',
#  'sayaxche',
#  'naantali',
#  'gyor',
#  'touros',
#  'viligili',
#  'lavrentiya',
#  'fare',
#  'linqiong',
#  'srednekolymsk',
#  'fairview',
#  'fukue',
#  'mehamn',
#  'lumberton',
#  'ancud',
#  'minas',
#  'coquimbo',
#  'yanam',
#  'gat',
#  'tumannyy',
#  'quang ngai',
#  'pori',
#  'gambela',
#  'nosy varika',
#  'samusu',
#  'babanusah',
#  'santa maria do suacui',
#  'meyungs',
#  'barabai',
#  'walvis bay',
#  'tacuarembo',
#  'vicuna',
#  'hargeysa',
#  'iranshahr',
#  'jacmel',
#  'kushmurun',
#  'cambados',
#  'matto',
#  'gualeguaychu',
#  'maarianhamina',
#  'prainha',
#  'mentok',
#  'ivybridge',
#  'tres arroyos',
#  'kristianstad',
#  'vostok',
#  'svetlogorsk',
#  'pedernales',
#  'jambi',
#  'sahrak',
#  'reinbek',
#  'ous',
#  'orotukan',
#  'hofn',
#  'gulariya',
#  'tual',
#  'puerto madero',
#  'campoverde',
#  'nechi',
#  'dien bien',
#  'batagay-alyta',
#  'conceicao do mato dentro',
#  'guozhen',
#  'sioux lookout',
#  'fort saint john',
#  'seoul',
#  'bonthe',
#  'balykshi',
#  'yambio',
#  'atlantic beach',
#  'topalu',
#  'wodonga',
#  'tostamaa',
#  'bershet',
#  'conde',
#  'belmonte',
#  'cookshire',
#  'petukhovo',
#  'ust-tsilma',
#  'berdigestyakh',
#  'roma',
#  'severomuysk',
#  'saint anthony',
#  'bukachacha',
#  'bundaberg',
#  'khorixas',
#  'muroto',
#  'anchorage',
#  'gornopravdinsk',
#  'borogontsy',
#  'saquena',
#  'saint-joseph',
#  'bulaevo',
#  'melfort',
#  'along',
#  'general pico',
#  'voh',
#  'meadow lake',
#  'litovko',
#  'batelov',
#  'lavumisa',
#  'vila velha',
#  'yar-sale',
#  'pemberton',
#  'sarakhs',
#  'bathsheba',
#  'tabou',
#  'emerald',
#  'san cristobal',
#  'lashio',
#  'luang prabang',
#  'bonwapitse',
#  'montepuez',
#  'chernyshevskiy',
#  'tigil',
#  'vieux-habitants',
#  'jutai',
#  'teahupoo',
#  'tyssedal',
#  'najran',
#  'kingaroy',
#  'ihosy',
#  'munster',
#  'kirakira',
#  'kpandu',
#  'mount gambier',
#  'santa cruz',
#  'fairbanks',
#  'bonavista',
#  'sorab',
#  'hailey',
#  'srivardhan',
#  'wang saphung',
#  'safaga',
#  'sinkat',
#  'ekibastuz',
#  'vila',
#  'kendari',
#  'pizarro',
#  'guanaja',
#  'malwan',
#  'ketchikan',
#  'misratah',
#  'vilhena',
#  'anloga',
#  'ambanja',
#  'nuuk',
#  'callaguip',
#  'raudeberg',
#  'vitim',
#  'verona',
#  'nemuro',
#  'point fortin',
#  'hendaye',
#  'hovd',
#  'ludvika',
#  'husavik',
#  'wad madani',
#  'brownwood',
#  'do gonbadan',
#  'santiago del estero',
#  'arman',
#  'nouakchott',
#  'paamiut',
#  'dolinsk',
#  'challapata',
#  'kodinsk',
#  'atambua',
#  'chapais',
#  'kosonsoy',
#  'mocuba',
#  'kerepehi',
#  'kuytun',
#  'praya',
#  'velenje',
#  'axim',
#  'bure',
#  'abha',
#  'mwene-ditu',
#  'porbandar',
#  'sechura',
#  'kaz',
#  'nurota',
#  'whitehorse',
#  'dubbo',
#  'tura',
#  'moa',
#  'darhan',
#  'buala',
#  'aporawan',
#  'at-bashi',
#  'juba',
#  'castlecomer',
#  'griffith',
#  'nizwa',
#  'dodge city',
#  'metro',
#  'alotau',
#  'mastic beach',
#  'la ronge',
#  'oyama',
#  'oromocto',
#  'bargal',
#  'hays',
#  'desdunes',
#  'kuala terengganu',
#  'nerchinskiy zavod',
#  'yarada',
#  'biak',
#  'uray',
#  'lubango',
#  'laguna',
#  'tungor',
#  'longhua',
#  'mayo',
#  'vestmanna',
#  'inhambane',
#  'tooele',
#  'oranjestad',
#  'staryy nadym',
#  'kumluca',
#  'duluth',
#  'carutapera',
#  'gewane',
#  'shimanovsk',
#  'kasongo-lunda',
#  'santa marta',
#  'bartica',
#  'floro',
#  'bodden town',
#  'hambantota',
#  'atbasar',
#  'bulawayo',
#  'maniitsoq',
#  'mobara',
#  'bud',
#  'broken hill',
#  'havre-saint-pierre',
#  'rajgarh',
#  'altay',
#  'shimoda',
#  'jalostotitlan',
#  'matagami',
#  'kizukuri',
#  'aasiaat',
#  'lom sak',
#  'caxito',
#  'jian',
#  'tongliao',
#  'rodbyhavn',
#  'fort wellington',
#  'sibiti',
#  'morden']

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7293673d7092ef3881f04c25546df694

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descr = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Country": city_country,
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Current Description": city_descr})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hualmay
# Processing Record 2 of Set 1 | chokurdakh
# Processing Record 3 of Set 1 | xinqing
# Processing Record 4 of Set 1 | vardo
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | kodiak
# Processing Record 8 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | ponta do sol
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | pitimbu
# Processing Record 14 of Set 1 | ilinskiy
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | barra do corda
# Processing Record 17 of Set 1 | nortelandia
# Processing Record 18 of Set 1 | port elizabeth
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | burica
# City not found. Skipping...
# Processing Record 21 of Set 1 | talnakh
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | aklavik
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | necochea
# Processing Record 26 of Set 1 | uxbridge
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | cap malheureux
# Processing Record 30 of Set 1 | cabildo
# Processing Record 31 of Set 1 | half moon bay
# Processing Record 32 of Set 1 | port-cartier
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | mawlaik
# Processing Record 35 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 1 | salmon creek
# Processing Record 37 of Set 1 | el jicaro
# Processing Record 38 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 1 | pacific grove
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | asau
# Processing Record 43 of Set 1 | kargil
# Processing Record 44 of Set 1 | kruisfontein
# Processing Record 45 of Set 1 | hakodate
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | kalemie
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | port macquarie
# Processing Record 1 of Set 2 | isilkul
# Processing Record 2 of Set 2 | leningradskiy
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | safakulevo
# Processing Record 5 of Set 2 | huercal-overa
# Processing Record 6 of Set 2 | provideniya
# Processing Record 7 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 2 | tasiilaq
# Processing Record 9 of Set 2 | taber
# Processing Record 10 of Set 2 | salvador
# Processing Record 11 of Set 2 | porto empedocle
# Processing Record 12 of Set 2 | cabo rojo
# Processing Record 13 of Set 2 | krasnoselkup
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | zhaoyuan
# Processing Record 16 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 2 | barrow
# Processing Record 18 of Set 2 | rio grande
# Processing Record 19 of Set 2 | ribeira grande
# Processing Record 20 of Set 2 | saint-philippe
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | cherskiy
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | acarau
# Processing Record 25 of Set 2 | vila franca do campo
# Processing Record 26 of Set 2 | olean
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 2 | quesnel
# Processing Record 30 of Set 2 | bilibino
# Processing Record 31 of Set 2 | morant bay
# Processing Record 32 of Set 2 | deputatskiy
# Processing Record 33 of Set 2 | naze
# Processing Record 34 of Set 2 | springdale
# Processing Record 35 of Set 2 | tuatapere
# Processing Record 36 of Set 2 | marawi
# Processing Record 37 of Set 2 | victoria
# Processing Record 38 of Set 2 | boda
# Processing Record 39 of Set 2 | ponta delgada
# Processing Record 40 of Set 2 | sinnamary
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | hasaki
# Processing Record 43 of Set 2 | mahebourg
# Processing Record 44 of Set 2 | sao filipe
# Processing Record 45 of Set 2 | kaputa
# Processing Record 46 of Set 2 | upernavik
# Processing Record 47 of Set 2 | porto santo
# Processing Record 48 of Set 2 | hun
# Processing Record 49 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 50 of Set 2 | garowe
# Processing Record 1 of Set 3 | nchelenge
# Processing Record 2 of Set 3 | torbay
# Processing Record 3 of Set 3 | udachnyy
# Processing Record 4 of Set 3 | hobart
# Processing Record 5 of Set 3 | grindavik
# Processing Record 6 of Set 3 | saskylakh
# Processing Record 7 of Set 3 | semey
# Processing Record 8 of Set 3 | lucea
# Processing Record 9 of Set 3 | luderitz
# Processing Record 10 of Set 3 | codrington
# Processing Record 11 of Set 3 | dukat
# Processing Record 12 of Set 3 | bowen
# Processing Record 13 of Set 3 | dingle
# Processing Record 14 of Set 3 | shelburne
# Processing Record 15 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 3 | new norfolk
# Processing Record 17 of Set 3 | beringovskiy
# Processing Record 18 of Set 3 | mineiros
# Processing Record 19 of Set 3 | faanui
# Processing Record 20 of Set 3 | butaritari
# Processing Record 21 of Set 3 | sambava
# Processing Record 22 of Set 3 | lawrenceburg
# Processing Record 23 of Set 3 | lamar
# Processing Record 24 of Set 3 | thinadhoo
# Processing Record 25 of Set 3 | general roca
# Processing Record 26 of Set 3 | thompson
# Processing Record 27 of Set 3 | san benito
# Processing Record 28 of Set 3 | przhevalskoye
# Processing Record 29 of Set 3 | yulara
# Processing Record 30 of Set 3 | puerto ayora
# Processing Record 31 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 3 | cidreira
# Processing Record 33 of Set 3 | kungurtug
# Processing Record 34 of Set 3 | khatanga
# Processing Record 35 of Set 3 | broome
# Processing Record 36 of Set 3 | bluff
# Processing Record 37 of Set 3 | bondo
# Processing Record 38 of Set 3 | ilulissat
# Processing Record 39 of Set 3 | virden
# Processing Record 40 of Set 3 | kapaa
# Processing Record 41 of Set 3 | kimbe
# Processing Record 42 of Set 3 | maragogi
# Processing Record 43 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 3 | marsa matruh
# Processing Record 46 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 3 | ballina
# Processing Record 48 of Set 3 | tutoia
# Processing Record 49 of Set 3 | namibe
# Processing Record 50 of Set 3 | los llanos de aridane
# Processing Record 1 of Set 4 | adrar
# Processing Record 2 of Set 4 | sitka
# Processing Record 3 of Set 4 | alice town
# Processing Record 4 of Set 4 | cravo norte
# Processing Record 5 of Set 4 | praia da vitoria
# Processing Record 6 of Set 4 | camopi
# Processing Record 7 of Set 4 | jarjis
# City not found. Skipping...
# Processing Record 8 of Set 4 | ahipara
# Processing Record 9 of Set 4 | port hedland
# Processing Record 10 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 4 | priargunsk
# Processing Record 12 of Set 4 | pangnirtung
# Processing Record 13 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 14 of Set 4 | constitucion
# Processing Record 15 of Set 4 | qaqortoq
# Processing Record 16 of Set 4 | kaeo
# Processing Record 17 of Set 4 | dongsheng
# Processing Record 18 of Set 4 | umm kaddadah
# Processing Record 19 of Set 4 | barinas
# Processing Record 20 of Set 4 | olafsvik
# Processing Record 21 of Set 4 | uarini
# Processing Record 22 of Set 4 | rockport
# Processing Record 23 of Set 4 | lagoa
# Processing Record 24 of Set 4 | berlevag
# Processing Record 25 of Set 4 | fortuna
# Processing Record 26 of Set 4 | rawson
# Processing Record 27 of Set 4 | kahului
# Processing Record 28 of Set 4 | muros
# Processing Record 29 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 4 | lyngdal
# Processing Record 31 of Set 4 | pevek
# Processing Record 32 of Set 4 | price
# Processing Record 33 of Set 4 | bubaque
# Processing Record 34 of Set 4 | vao
# Processing Record 35 of Set 4 | santa rosa
# Processing Record 36 of Set 4 | dikson
# Processing Record 37 of Set 4 | bandarbeyla
# Processing Record 38 of Set 4 | ucluelet
# Processing Record 39 of Set 4 | champerico
# Processing Record 40 of Set 4 | hithadhoo
# Processing Record 41 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 4 | mudyuga
# City not found. Skipping...
# Processing Record 43 of Set 4 | meulaboh
# Processing Record 44 of Set 4 | beian
# Processing Record 45 of Set 4 | shaunavon
# Processing Record 46 of Set 4 | colomi
# Processing Record 47 of Set 4 | harwich
# Processing Record 48 of Set 4 | atasu
# Processing Record 49 of Set 4 | killybegs
# Processing Record 50 of Set 4 | ossora
# Processing Record 1 of Set 5 | havoysund
# Processing Record 2 of Set 5 | flinders
# Processing Record 3 of Set 5 | iskateley
# Processing Record 4 of Set 5 | inirida
# Processing Record 5 of Set 5 | lere
# Processing Record 6 of Set 5 | chuy
# Processing Record 7 of Set 5 | japura
# Processing Record 8 of Set 5 | verkhnevilyuysk
# Processing Record 9 of Set 5 | ambon
# Processing Record 10 of Set 5 | sao joao da barra
# Processing Record 11 of Set 5 | la candelaria
# Processing Record 12 of Set 5 | norman wells
# Processing Record 13 of Set 5 | bourail
# Processing Record 14 of Set 5 | mar del plata
# Processing Record 15 of Set 5 | byron bay
# Processing Record 16 of Set 5 | vuktyl
# Processing Record 17 of Set 5 | pisco
# Processing Record 18 of Set 5 | nanfeng
# Processing Record 19 of Set 5 | teya
# Processing Record 20 of Set 5 | zhanaozen
# Processing Record 21 of Set 5 | cabo san lucas
# Processing Record 22 of Set 5 | sola
# Processing Record 23 of Set 5 | souillac
# Processing Record 24 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 25 of Set 5 | beloha
# Processing Record 26 of Set 5 | cockburn town
# Processing Record 27 of Set 5 | polunochnoye
# Processing Record 28 of Set 5 | caravelas
# Processing Record 29 of Set 5 | buxtehude
# Processing Record 30 of Set 5 | antofagasta
# Processing Record 31 of Set 5 | narsaq
# Processing Record 32 of Set 5 | pundaguitan
# Processing Record 33 of Set 5 | hamilton
# Processing Record 34 of Set 5 | kirovskiy
# Processing Record 35 of Set 5 | tautira
# Processing Record 36 of Set 5 | lorengau
# Processing Record 37 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 5 | okato
# Processing Record 39 of Set 5 | pokaran
# Processing Record 40 of Set 5 | si sa ket
# Processing Record 41 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 42 of Set 5 | katsuura
# Processing Record 43 of Set 5 | lar
# Processing Record 44 of Set 5 | amara
# Processing Record 45 of Set 5 | saint-pierre
# Processing Record 46 of Set 5 | kidal
# Processing Record 47 of Set 5 | bani
# Processing Record 48 of Set 5 | iqaluit
# Processing Record 49 of Set 5 | dicabisagan
# Processing Record 50 of Set 5 | tatarskaya pishlya
# Processing Record 1 of Set 6 | pechenga
# Processing Record 2 of Set 6 | kormilovka
# Processing Record 3 of Set 6 | port-gentil
# Processing Record 4 of Set 6 | zunyi
# Processing Record 5 of Set 6 | brae
# Processing Record 6 of Set 6 | ponnani
# Processing Record 7 of Set 6 | severo-kurilsk
# Processing Record 8 of Set 6 | ejura
# Processing Record 9 of Set 6 | cabra
# Processing Record 10 of Set 6 | college
# Processing Record 11 of Set 6 | progreso
# Processing Record 12 of Set 6 | labuhan
# Processing Record 13 of Set 6 | clyde river
# Processing Record 14 of Set 6 | bengkulu
# Processing Record 15 of Set 6 | vestmannaeyjar
# Processing Record 16 of Set 6 | akhtanizovskaya
# Processing Record 17 of Set 6 | yashkino
# Processing Record 18 of Set 6 | kieta
# Processing Record 19 of Set 6 | ukiah
# Processing Record 20 of Set 6 | isangel
# Processing Record 21 of Set 6 | nador
# Processing Record 22 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 23 of Set 6 | shenjiamen
# Processing Record 24 of Set 6 | christchurch
# Processing Record 25 of Set 6 | buckingham
# Processing Record 26 of Set 6 | raichur
# Processing Record 27 of Set 6 | kashi
# Processing Record 28 of Set 6 | carnarvon
# Processing Record 29 of Set 6 | port augusta
# Processing Record 30 of Set 6 | henties bay
# Processing Record 31 of Set 6 | dawson creek
# Processing Record 32 of Set 6 | portland
# Processing Record 33 of Set 6 | faya
# Processing Record 34 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 35 of Set 6 | salalah
# Processing Record 36 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 37 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 6 | yumen
# Processing Record 39 of Set 6 | newport beach
# Processing Record 40 of Set 6 | nizhnyaya tavda
# Processing Record 41 of Set 6 | coos bay
# Processing Record 42 of Set 6 | labytnangi
# Processing Record 43 of Set 6 | jiaohe
# Processing Record 44 of Set 6 | nishihara
# Processing Record 45 of Set 6 | padang
# Processing Record 46 of Set 6 | kindu
# Processing Record 47 of Set 6 | bambous virieux
# Processing Record 48 of Set 6 | elko
# Processing Record 49 of Set 6 | bangui
# Processing Record 50 of Set 6 | rafaela
# Processing Record 1 of Set 7 | vanimo
# Processing Record 2 of Set 7 | haines junction
# Processing Record 3 of Set 7 | gallipoli
# Processing Record 4 of Set 7 | saint-francois
# Processing Record 5 of Set 7 | esperance
# Processing Record 6 of Set 7 | honningsvag
# Processing Record 7 of Set 7 | muyezerskiy
# Processing Record 8 of Set 7 | horsham
# Processing Record 9 of Set 7 | lantawan
# Processing Record 10 of Set 7 | northam
# Processing Record 11 of Set 7 | kaitangata
# Processing Record 12 of Set 7 | constanta
# Processing Record 13 of Set 7 | trofors
# Processing Record 14 of Set 7 | utmanzai
# Processing Record 15 of Set 7 | airai
# Processing Record 16 of Set 7 | porto novo
# Processing Record 17 of Set 7 | yerbogachen
# Processing Record 18 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 19 of Set 7 | san patricio
# Processing Record 20 of Set 7 | sagopshi
# Processing Record 21 of Set 7 | dijkot
# Processing Record 22 of Set 7 | merauke
# Processing Record 23 of Set 7 | aksarka
# Processing Record 24 of Set 7 | sandwick
# Processing Record 25 of Set 7 | cuxhaven
# Processing Record 26 of Set 7 | fengkou
# Processing Record 27 of Set 7 | vaitape
# Processing Record 28 of Set 7 | sao gabriel da cachoeira
# Processing Record 29 of Set 7 | usinsk
# Processing Record 30 of Set 7 | grand-lahou
# Processing Record 31 of Set 7 | chake chake
# Processing Record 32 of Set 7 | chippewa falls
# Processing Record 33 of Set 7 | micomeseng
# Processing Record 34 of Set 7 | nikolskoye
# Processing Record 35 of Set 7 | calvillo
# Processing Record 36 of Set 7 | basco
# Processing Record 37 of Set 7 | geraldton
# Processing Record 38 of Set 7 | staveley
# Processing Record 39 of Set 7 | uyemskiy
# Processing Record 40 of Set 7 | magdagachi
# Processing Record 41 of Set 7 | te anau
# Processing Record 42 of Set 7 | the valley
# Processing Record 43 of Set 7 | togur
# Processing Record 44 of Set 7 | namatanai
# Processing Record 45 of Set 7 | opuwo
# Processing Record 46 of Set 7 | bay roberts
# Processing Record 47 of Set 7 | saldanha
# Processing Record 48 of Set 7 | powell
# Processing Record 49 of Set 7 | mareeba
# Processing Record 50 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 1 of Set 8 | ulladulla
# Processing Record 2 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 8 | saint george
# Processing Record 4 of Set 8 | viedma
# Processing Record 5 of Set 8 | san jeronimo
# Processing Record 6 of Set 8 | freeport
# Processing Record 7 of Set 8 | saint-michel-des-saints
# Processing Record 8 of Set 8 | voznesenye
# Processing Record 9 of Set 8 | mandalgovi
# Processing Record 10 of Set 8 | longyearbyen
# Processing Record 11 of Set 8 | moose factory
# Processing Record 12 of Set 8 | aborlan
# Processing Record 13 of Set 8 | tiksi
# Processing Record 14 of Set 8 | tadine
# Processing Record 15 of Set 8 | tenenkou
# Processing Record 16 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 8 | mecca
# Processing Record 18 of Set 8 | alofi
# Processing Record 19 of Set 8 | rovaniemi
# Processing Record 20 of Set 8 | redmond
# Processing Record 21 of Set 8 | asfi
# Processing Record 22 of Set 8 | pangoa
# Processing Record 23 of Set 8 | olinda
# Processing Record 24 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 8 | saint-georges
# Processing Record 26 of Set 8 | ramgarh
# Processing Record 27 of Set 8 | san vicente
# Processing Record 28 of Set 8 | staromyshastovskaya
# Processing Record 29 of Set 8 | monrovia
# Processing Record 30 of Set 8 | la trinidad
# Processing Record 31 of Set 8 | ryotsu
# Processing Record 32 of Set 8 | verkhnyaya inta
# Processing Record 33 of Set 8 | san jose
# Processing Record 34 of Set 8 | acapulco
# Processing Record 35 of Set 8 | presidente venceslau
# Processing Record 36 of Set 8 | pak phanang
# Processing Record 37 of Set 8 | coahuayana
# Processing Record 38 of Set 8 | elliot lake
# Processing Record 39 of Set 8 | xixiang
# Processing Record 40 of Set 8 | saint-augustin
# Processing Record 41 of Set 8 | tazovskiy
# Processing Record 42 of Set 8 | cayenne
# Processing Record 43 of Set 8 | ixtapa
# Processing Record 44 of Set 8 | komsomolskiy
# Processing Record 45 of Set 8 | chuguyevka
# Processing Record 46 of Set 8 | volnovakha
# Processing Record 47 of Set 8 | sibu
# Processing Record 48 of Set 8 | luwuk
# Processing Record 49 of Set 8 | sol-iletsk
# Processing Record 50 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 1 of Set 9 | port hardy
# Processing Record 2 of Set 9 | dunedin
# Processing Record 3 of Set 9 | mariental
# Processing Record 4 of Set 9 | korla
# Processing Record 5 of Set 9 | leh
# Processing Record 6 of Set 9 | phaltan
# Processing Record 7 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 9 | smoky lake
# Processing Record 9 of Set 9 | weihai
# Processing Record 10 of Set 9 | mittweida
# Processing Record 11 of Set 9 | sumenep
# Processing Record 12 of Set 9 | warwick
# Processing Record 13 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 9 | geresk
# City not found. Skipping...
# Processing Record 15 of Set 9 | balikpapan
# Processing Record 16 of Set 9 | soyo
# Processing Record 17 of Set 9 | lasa
# Processing Record 18 of Set 9 | lebu
# Processing Record 19 of Set 9 | hervey bay
# Processing Record 20 of Set 9 | turbana
# Processing Record 21 of Set 9 | san quintin
# Processing Record 22 of Set 9 | lebanon
# Processing Record 23 of Set 9 | burnie
# Processing Record 24 of Set 9 | itoman
# Processing Record 25 of Set 9 | ust-nera
# Processing Record 26 of Set 9 | suruc
# Processing Record 27 of Set 9 | rabo de peixe
# Processing Record 28 of Set 9 | agadez
# Processing Record 29 of Set 9 | sobolevo
# Processing Record 30 of Set 9 | bara
# Processing Record 31 of Set 9 | fort nelson
# Processing Record 32 of Set 9 | dali
# Processing Record 33 of Set 9 | reyes
# Processing Record 34 of Set 9 | barberton
# Processing Record 35 of Set 9 | nome
# Processing Record 36 of Set 9 | old road
# City not found. Skipping...
# Processing Record 37 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 9 | ortakoy
# Processing Record 39 of Set 9 | kirensk
# Processing Record 40 of Set 9 | dandong
# Processing Record 41 of Set 9 | mersing
# Processing Record 42 of Set 9 | poum
# Processing Record 43 of Set 9 | hokitika
# Processing Record 44 of Set 9 | high rock
# Processing Record 45 of Set 9 | kalmunai
# Processing Record 46 of Set 9 | nabire
# Processing Record 47 of Set 9 | tiznit
# Processing Record 48 of Set 9 | lampang
# Processing Record 49 of Set 9 | lindi
# Processing Record 50 of Set 9 | madisonville
# Processing Record 1 of Set 10 | sorong
# Processing Record 2 of Set 10 | minab
# Processing Record 3 of Set 10 | san juan de abajo
# Processing Record 4 of Set 10 | eureka
# Processing Record 5 of Set 10 | erenhot
# Processing Record 6 of Set 10 | huarmey
# Processing Record 7 of Set 10 | aswan
# Processing Record 8 of Set 10 | paramonga
# Processing Record 9 of Set 10 | birin
# Processing Record 10 of Set 10 | ostrovnoy
# Processing Record 11 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 13 of Set 10 | onega
# Processing Record 14 of Set 10 | mount isa
# Processing Record 15 of Set 10 | shiyan
# Processing Record 16 of Set 10 | palmer
# Processing Record 17 of Set 10 | san mateo del mar
# Processing Record 18 of Set 10 | camacha
# Processing Record 19 of Set 10 | muriti
# Processing Record 20 of Set 10 | muzaffarabad
# Processing Record 21 of Set 10 | roald
# Processing Record 22 of Set 10 | mandan
# Processing Record 23 of Set 10 | presidencia roque saenz pena
# Processing Record 24 of Set 10 | porgera
# Processing Record 25 of Set 10 | gua musang
# Processing Record 26 of Set 10 | bafq
# Processing Record 27 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 10 | acacoyagua
# Processing Record 29 of Set 10 | inuvik
# Processing Record 30 of Set 10 | valparaiso
# Processing Record 31 of Set 10 | waddan
# Processing Record 32 of Set 10 | kununurra
# Processing Record 33 of Set 10 | beyneu
# Processing Record 34 of Set 10 | nanortalik
# Processing Record 35 of Set 10 | kulhudhuffushi
# Processing Record 36 of Set 10 | pandan
# Processing Record 37 of Set 10 | barentu
# Processing Record 38 of Set 10 | eura
# Processing Record 39 of Set 10 | alice springs
# Processing Record 40 of Set 10 | orcopampa
# Processing Record 41 of Set 10 | jardim
# Processing Record 42 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 10 | primorsko
# Processing Record 44 of Set 10 | mackay
# Processing Record 45 of Set 10 | mattru
# Processing Record 46 of Set 10 | ust-ilimsk
# Processing Record 47 of Set 10 | evensk
# Processing Record 48 of Set 10 | wenatchee
# Processing Record 49 of Set 10 | fort abbas
# Processing Record 50 of Set 10 | moron
# Processing Record 1 of Set 11 | guerrero negro
# Processing Record 2 of Set 11 | toora-khem
# Processing Record 3 of Set 11 | kavieng
# Processing Record 4 of Set 11 | pavlodar
# Processing Record 5 of Set 11 | rumford
# Processing Record 6 of Set 11 | bay city
# Processing Record 7 of Set 11 | robertsport
# Processing Record 8 of Set 11 | votkinsk
# Processing Record 9 of Set 11 | xining
# Processing Record 10 of Set 11 | imbituba
# Processing Record 11 of Set 11 | leninskoye
# Processing Record 12 of Set 11 | maningrida
# Processing Record 13 of Set 11 | avera
# Processing Record 14 of Set 11 | bukene
# Processing Record 15 of Set 11 | manokwari
# Processing Record 16 of Set 11 | cordoba
# Processing Record 17 of Set 11 | batangafo
# Processing Record 18 of Set 11 | benghazi
# Processing Record 19 of Set 11 | iralaya
# Processing Record 20 of Set 11 | tanout
# Processing Record 21 of Set 11 | ongandjera
# Processing Record 22 of Set 11 | tilichiki
# Processing Record 23 of Set 11 | ternate
# Processing Record 24 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 11 | chamba
# Processing Record 26 of Set 11 | sayaxche
# Processing Record 27 of Set 11 | naantali
# Processing Record 28 of Set 11 | gyor
# Processing Record 29 of Set 11 | touros
# Processing Record 30 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 11 | lavrentiya
# Processing Record 32 of Set 11 | fare
# Processing Record 33 of Set 11 | linqiong
# Processing Record 34 of Set 11 | srednekolymsk
# Processing Record 35 of Set 11 | fairview
# Processing Record 36 of Set 11 | fukue
# Processing Record 37 of Set 11 | mehamn
# Processing Record 38 of Set 11 | lumberton
# Processing Record 39 of Set 11 | ancud
# Processing Record 40 of Set 11 | minas
# Processing Record 41 of Set 11 | coquimbo
# Processing Record 42 of Set 11 | yanam
# Processing Record 43 of Set 11 | gat
# Processing Record 44 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 11 | quang ngai
# Processing Record 46 of Set 11 | pori
# Processing Record 47 of Set 11 | gambela
# Processing Record 48 of Set 11 | nosy varika
# Processing Record 49 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 1 of Set 12 | santa maria do suacui
# Processing Record 2 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 12 | barabai
# Processing Record 4 of Set 12 | walvis bay
# Processing Record 5 of Set 12 | tacuarembo
# Processing Record 6 of Set 12 | vicuna
# Processing Record 7 of Set 12 | hargeysa
# Processing Record 8 of Set 12 | iranshahr
# Processing Record 9 of Set 12 | jacmel
# Processing Record 10 of Set 12 | kushmurun
# Processing Record 11 of Set 12 | cambados
# Processing Record 12 of Set 12 | matto
# City not found. Skipping...
# Processing Record 13 of Set 12 | gualeguaychu
# Processing Record 14 of Set 12 | maarianhamina
# Processing Record 15 of Set 12 | prainha
# Processing Record 16 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 12 | ivybridge
# Processing Record 18 of Set 12 | tres arroyos
# Processing Record 19 of Set 12 | kristianstad
# Processing Record 20 of Set 12 | vostok
# Processing Record 21 of Set 12 | svetlogorsk
# Processing Record 22 of Set 12 | pedernales
# Processing Record 23 of Set 12 | jambi
# Processing Record 24 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 25 of Set 12 | reinbek
# Processing Record 26 of Set 12 | ous
# Processing Record 27 of Set 12 | orotukan
# Processing Record 28 of Set 12 | hofn
# Processing Record 29 of Set 12 | gulariya
# Processing Record 30 of Set 12 | tual
# Processing Record 31 of Set 12 | puerto madero
# Processing Record 32 of Set 12 | campoverde
# Processing Record 33 of Set 12 | nechi
# Processing Record 34 of Set 12 | dien bien
# City not found. Skipping...
# Processing Record 35 of Set 12 | batagay-alyta
# Processing Record 36 of Set 12 | conceicao do mato dentro
# Processing Record 37 of Set 12 | guozhen
# Processing Record 38 of Set 12 | sioux lookout
# Processing Record 39 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 40 of Set 12 | seoul
# Processing Record 41 of Set 12 | bonthe
# Processing Record 42 of Set 12 | balykshi
# Processing Record 43 of Set 12 | yambio
# Processing Record 44 of Set 12 | atlantic beach
# Processing Record 45 of Set 12 | topalu
# Processing Record 46 of Set 12 | wodonga
# Processing Record 47 of Set 12 | tostamaa
# City not found. Skipping...
# Processing Record 48 of Set 12 | bershet
# Processing Record 49 of Set 12 | conde
# Processing Record 50 of Set 12 | belmonte
# Processing Record 1 of Set 13 | cookshire
# City not found. Skipping...
# Processing Record 2 of Set 13 | petukhovo
# Processing Record 3 of Set 13 | ust-tsilma
# Processing Record 4 of Set 13 | berdigestyakh
# Processing Record 5 of Set 13 | roma
# Processing Record 6 of Set 13 | severomuysk
# Processing Record 7 of Set 13 | saint anthony
# Processing Record 8 of Set 13 | bukachacha
# Processing Record 9 of Set 13 | bundaberg
# Processing Record 10 of Set 13 | khorixas
# Processing Record 11 of Set 13 | muroto
# Processing Record 12 of Set 13 | anchorage
# Processing Record 13 of Set 13 | gornopravdinsk
# Processing Record 14 of Set 13 | borogontsy
# Processing Record 15 of Set 13 | saquena
# Processing Record 16 of Set 13 | saint-joseph
# Processing Record 17 of Set 13 | bulaevo
# Processing Record 18 of Set 13 | melfort
# Processing Record 19 of Set 13 | along
# Processing Record 20 of Set 13 | general pico
# Processing Record 21 of Set 13 | voh
# Processing Record 22 of Set 13 | meadow lake
# Processing Record 23 of Set 13 | litovko
# Processing Record 24 of Set 13 | batelov
# Processing Record 25 of Set 13 | lavumisa
# Processing Record 26 of Set 13 | vila velha
# Processing Record 27 of Set 13 | yar-sale
# Processing Record 28 of Set 13 | pemberton
# Processing Record 29 of Set 13 | sarakhs
# Processing Record 30 of Set 13 | bathsheba
# Processing Record 31 of Set 13 | tabou
# Processing Record 32 of Set 13 | emerald
# Processing Record 33 of Set 13 | san cristobal
# Processing Record 34 of Set 13 | lashio
# Processing Record 35 of Set 13 | luang prabang
# Processing Record 36 of Set 13 | bonwapitse
# Processing Record 37 of Set 13 | montepuez
# Processing Record 38 of Set 13 | chernyshevskiy
# Processing Record 39 of Set 13 | tigil
# Processing Record 40 of Set 13 | vieux-habitants
# Processing Record 41 of Set 13 | jutai
# Processing Record 42 of Set 13 | teahupoo
# Processing Record 43 of Set 13 | tyssedal
# Processing Record 44 of Set 13 | najran
# Processing Record 45 of Set 13 | kingaroy
# Processing Record 46 of Set 13 | ihosy
# Processing Record 47 of Set 13 | munster
# Processing Record 48 of Set 13 | kirakira
# Processing Record 49 of Set 13 | kpandu
# Processing Record 50 of Set 13 | mount gambier
# Processing Record 1 of Set 14 | santa cruz
# Processing Record 2 of Set 14 | fairbanks
# Processing Record 3 of Set 14 | bonavista
# Processing Record 4 of Set 14 | sorab
# Processing Record 5 of Set 14 | hailey
# Processing Record 6 of Set 14 | srivardhan
# Processing Record 7 of Set 14 | wang saphung
# Processing Record 8 of Set 14 | safaga
# Processing Record 9 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 10 of Set 14 | ekibastuz
# Processing Record 11 of Set 14 | vila
# Processing Record 12 of Set 14 | kendari
# Processing Record 13 of Set 14 | pizarro
# Processing Record 14 of Set 14 | guanaja
# Processing Record 15 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 14 | ketchikan
# Processing Record 17 of Set 14 | misratah
# Processing Record 18 of Set 14 | vilhena
# Processing Record 19 of Set 14 | anloga
# Processing Record 20 of Set 14 | ambanja
# Processing Record 21 of Set 14 | nuuk
# Processing Record 22 of Set 14 | callaguip
# Processing Record 23 of Set 14 | raudeberg
# Processing Record 24 of Set 14 | vitim
# Processing Record 25 of Set 14 | verona
# Processing Record 26 of Set 14 | nemuro
# Processing Record 27 of Set 14 | point fortin
# Processing Record 28 of Set 14 | hendaye
# Processing Record 29 of Set 14 | hovd
# Processing Record 30 of Set 14 | ludvika
# Processing Record 31 of Set 14 | husavik
# Processing Record 32 of Set 14 | wad madani
# Processing Record 33 of Set 14 | brownwood
# Processing Record 34 of Set 14 | do gonbadan
# Processing Record 35 of Set 14 | santiago del estero
# Processing Record 36 of Set 14 | arman
# Processing Record 37 of Set 14 | nouakchott
# Processing Record 38 of Set 14 | paamiut
# Processing Record 39 of Set 14 | dolinsk
# Processing Record 40 of Set 14 | challapata
# Processing Record 41 of Set 14 | kodinsk
# Processing Record 42 of Set 14 | atambua
# Processing Record 43 of Set 14 | chapais
# Processing Record 44 of Set 14 | kosonsoy
# Processing Record 45 of Set 14 | mocuba
# Processing Record 46 of Set 14 | kerepehi
# Processing Record 47 of Set 14 | kuytun
# Processing Record 48 of Set 14 | praya
# Processing Record 49 of Set 14 | velenje
# Processing Record 50 of Set 14 | axim
# Processing Record 1 of Set 15 | bure
# Processing Record 2 of Set 15 | abha
# Processing Record 3 of Set 15 | mwene-ditu
# Processing Record 4 of Set 15 | porbandar
# Processing Record 5 of Set 15 | sechura
# Processing Record 6 of Set 15 | kaz
# Processing Record 7 of Set 15 | nurota
# Processing Record 8 of Set 15 | whitehorse
# Processing Record 9 of Set 15 | dubbo
# Processing Record 10 of Set 15 | tura
# Processing Record 11 of Set 15 | moa
# Processing Record 12 of Set 15 | darhan
# Processing Record 13 of Set 15 | buala
# Processing Record 14 of Set 15 | aporawan
# City not found. Skipping...
# Processing Record 15 of Set 15 | at-bashi
# Processing Record 16 of Set 15 | juba
# Processing Record 17 of Set 15 | castlecomer
# Processing Record 18 of Set 15 | griffith
# Processing Record 19 of Set 15 | nizwa
# Processing Record 20 of Set 15 | dodge city
# Processing Record 21 of Set 15 | metro
# Processing Record 22 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 15 | mastic beach
# Processing Record 24 of Set 15 | la ronge
# Processing Record 25 of Set 15 | oyama
# Processing Record 26 of Set 15 | oromocto
# Processing Record 27 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 15 | hays
# Processing Record 29 of Set 15 | desdunes
# Processing Record 30 of Set 15 | kuala terengganu
# Processing Record 31 of Set 15 | nerchinskiy zavod
# Processing Record 32 of Set 15 | yarada
# Processing Record 33 of Set 15 | biak
# Processing Record 34 of Set 15 | uray
# Processing Record 35 of Set 15 | lubango
# Processing Record 36 of Set 15 | laguna
# Processing Record 37 of Set 15 | tungor
# Processing Record 38 of Set 15 | longhua
# Processing Record 39 of Set 15 | mayo
# Processing Record 40 of Set 15 | vestmanna
# Processing Record 41 of Set 15 | inhambane
# Processing Record 42 of Set 15 | tooele
# Processing Record 43 of Set 15 | oranjestad
# Processing Record 44 of Set 15 | staryy nadym
# Processing Record 45 of Set 15 | kumluca
# Processing Record 46 of Set 15 | duluth
# Processing Record 47 of Set 15 | carutapera
# Processing Record 48 of Set 15 | gewane
# Processing Record 49 of Set 15 | shimanovsk
# Processing Record 50 of Set 15 | kasongo-lunda
# Processing Record 1 of Set 16 | santa marta
# Processing Record 2 of Set 16 | bartica
# Processing Record 3 of Set 16 | floro
# Processing Record 4 of Set 16 | bodden town
# Processing Record 5 of Set 16 | hambantota
# Processing Record 6 of Set 16 | atbasar
# Processing Record 7 of Set 16 | bulawayo
# Processing Record 8 of Set 16 | maniitsoq
# Processing Record 9 of Set 16 | mobara
# Processing Record 10 of Set 16 | bud
# Processing Record 11 of Set 16 | broken hill
# Processing Record 12 of Set 16 | havre-saint-pierre
# Processing Record 13 of Set 16 | rajgarh
# Processing Record 14 of Set 16 | altay
# Processing Record 15 of Set 16 | shimoda
# Processing Record 16 of Set 16 | jalostotitlan
# Processing Record 17 of Set 16 | matagami
# Processing Record 18 of Set 16 | kizukuri
# Processing Record 19 of Set 16 | aasiaat
# Processing Record 20 of Set 16 | lom sak
# Processing Record 21 of Set 16 | caxito
# Processing Record 22 of Set 16 | jian
# Processing Record 23 of Set 16 | tongliao
# Processing Record 24 of Set 16 | rodbyhavn
# Processing Record 25 of Set 16 | fort wellington
# Processing Record 26 of Set 16 | sibiti
# Processing Record 27 of Set 16 | morden
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Hualmay',
#   'Country': 'PE',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 69.87,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 5.95,
#   'Current Description': 'broken clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 3.36,
#   'Humidity': 93,
#   'Cloudiness': 97,
#   'Wind Speed': 5.19,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Xinqing',
#   'Country': 'CN',
#   'Lat': 48.2333,
#   'Lng': 129.5,
#   'Max Temp': 36.27,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.84,
#   'Current Description': 'light snow'},
#  {'City': 'Vardo',
#   'Country': 'NO',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 33.8,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 79.72,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 14.63,
#   'Current Description': 'clear sky'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 62.01,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 44.6,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 59,
#   'Humidity': 94,
#   'Cloudiness': 98,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 62.6,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 17.27,
#   'Current Description': 'few clouds'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 61,
#   'Humidity': 87,
#   'Cloudiness': 21,
#   'Wind Speed': 10,
#   'Current Description': 'few clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -14.8,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Current Description': 'few clouds'},
#  {'City': 'Pitimbu',
#   'Country': 'BR',
#   'Lat': -7.4706,
#   'Lng': -34.8086,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Ilinskiy',
#   'Country': 'RU',
#   'Lat': 55.619,
#   'Lng': 38.1182,
#   'Max Temp': 30,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Description': 'clear sky'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 82.35,
#   'Humidity': 30,
#   'Cloudiness': 54,
#   'Wind Speed': 2.37,
#   'Current Description': 'broken clouds'},
#  {'City': 'Barra Do Corda',
#   'Country': 'BR',
#   'Lat': -5.5,
#   'Lng': -45.25,
#   'Max Temp': 71.78,
#   'Humidity': 97,
#   'Cloudiness': 51,
#   'Wind Speed': 2.86,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nortelandia',
#   'Country': 'BR',
#   'Lat': -14.4547,
#   'Lng': -56.8028,
#   'Max Temp': 73.72,
#   'Humidity': 81,
#   'Cloudiness': 23,
#   'Wind Speed': 2.08,
#   'Current Description': 'few clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 64.4,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 53.01,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Current Description': 'light rain'},
#  {'City': 'Talnakh',
#   'Country': 'RU',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': -5.64,
#   'Humidity': 97,
#   'Cloudiness': 97,
#   'Wind Speed': 7.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 64.99,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Current Description': 'clear sky'},
#  {'City': 'Aklavik',
#   'Country': 'CA',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': -2.2,
#   'Humidity': 50,
#   'Cloudiness': 27,
#   'Wind Speed': 3.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Necochea',
#   'Country': 'AR',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 59,
#   'Humidity': 88,
#   'Cloudiness': 38,
#   'Wind Speed': 7.2,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Uxbridge',
#   'Country': 'US',
#   'Lat': 42.0773,
#   'Lng': -71.6295,
#   'Max Temp': 53.01,
#   'Humidity': 2,
#   'Cloudiness': 100,
#   'Wind Speed': 10,
#   'Current Description': 'moderate rain'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 41,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 65.19,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 19.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cap Malheureux',
#   'Country': 'MU',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp': 80.01,
#   'Humidity': 76,
#   'Cloudiness': 22,
#   'Wind Speed': 4.65,
#   'Current Description': 'few clouds'},
#  {'City': 'Cabildo',
#   'Country': 'AR',
#   'Lat': -38.4842,
#   'Lng': -61.8954,
#   'Max Temp': 55,
#   'Humidity': 93,
#   'Cloudiness': 96,
#   'Wind Speed': 7.34,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Half Moon Bay',
#   'Country': 'US',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 62.6,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'mist'},
#  {'City': 'Port-Cartier',
#   'Country': 'CA',
#   'Lat': 50.0334,
#   'Lng': -66.8654,
#   'Max Temp': 27,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 24.16,
#   'Current Description': 'snow'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 12.2,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 21.85,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mawlaik',
#   'Country': 'MM',
#   'Lat': 23.6333,
#   'Lng': 94.4167,
#   'Max Temp': 94.82,
#   'Humidity': 11,
#   'Cloudiness': 92,
#   'Wind Speed': 0.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Salmon Creek',
#   'Country': 'US',
#   'Lat': 45.7107,
#   'Lng': -122.649,
#   'Max Temp': 42.8,
#   'Humidity': 56,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Current Description': 'light rain'},
#  {'City': 'El Jicaro',
#   'Country': 'GT',
#   'Lat': 14.9167,
#   'Lng': -89.9,
#   'Max Temp': 75.61,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 4.21,
#   'Current Description': 'clear sky'},
#  {'City': 'Pacific Grove',
#   'Country': 'US',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 54,
#   'Humidity': 76,
#   'Cloudiness': 1,
#   'Wind Speed': 3.09,
#   'Current Description': 'clear sky'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 42.8,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Current Description': 'few clouds'},
#  {'City': 'Asau',
#   'Country': 'RO',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 35.01,
#   'Humidity': 44,
#   'Cloudiness': 24,
#   'Wind Speed': 5.23,
#   'Current Description': 'few clouds'},
#  {'City': 'Kargil',
#   'Country': 'IN',
#   'Lat': 34.5667,
#   'Lng': 76.1,
#   'Max Temp': 36.68,
#   'Humidity': 76,
#   'Cloudiness': 99,
#   'Wind Speed': 9.78,
#   'Current Description': 'light snow'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 60.01,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hakodate',
#   'Country': 'JP',
#   'Lat': 41.7758,
#   'Lng': 140.7367,
#   'Max Temp': 55.4,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 77.11,
#   'Humidity': 90,
#   'Cloudiness': 42,
#   'Wind Speed': 9.48,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 50,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 13.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kalemie',
#   'Country': 'CD',
#   'Lat': -5.9475,
#   'Lng': 29.1947,
#   'Max Temp': 69.73,
#   'Humidity': 84,
#   'Cloudiness': 96,
#   'Wind Speed': 1.66,
#   'Current Description': 'light rain'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 73.4,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'light rain'},
#  {'City': 'Port Macquarie',
#   'Country': 'AU',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 77,
#   'Humidity': 47,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'light rain'},
#  {'City': 'Isilkul',
#   'Country': 'RU',
#   'Lat': 54.9109,
#   'Lng': 71.2728,
#   'Max Temp': 15.91,
#   'Humidity': 82,
#   'Cloudiness': 78,
#   'Wind Speed': 18.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 1.45,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.78,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 36,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 23.09,
#   'Current Description': 'light rain'},
#  {'City': 'Safakulevo',
#   'Country': 'RU',
#   'Lat': 54.9901,
#   'Lng': 62.5442,
#   'Max Temp': 21.7,
#   'Humidity': 92,
#   'Cloudiness': 42,
#   'Wind Speed': 11.59,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Huercal-Overa',
#   'Country': 'ES',
#   'Lat': 37.389,
#   'Lng': -1.9454,
#   'Max Temp': 51.01,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 5.32,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 19.47,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 18.92,
#   'Current Description': 'light snow'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 14,
#   'Humidity': 52,
#   'Cloudiness': 95,
#   'Wind Speed': 5.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Taber',
#   'Country': 'CA',
#   'Lat': 49.8167,
#   'Lng': -112.1518,
#   'Max Temp': 50,
#   'Humidity': 43,
#   'Cloudiness': 8,
#   'Wind Speed': 23.02,
#   'Current Description': 'clear sky'},
#  {'City': 'Salvador',
#   'Country': 'SV',
#   'Lat': 13.8333,
#   'Lng': -88.9167,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 1.14,
#   'Current Description': 'clear sky'},
#  {'City': 'Porto Empedocle',
#   'Country': 'IT',
#   'Lat': 37.2934,
#   'Lng': 13.5264,
#   'Max Temp': 54,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 5.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Cabo Rojo',
#   'Country': 'PR',
#   'Lat': 18.0866,
#   'Lng': -67.1457,
#   'Max Temp': 75.99,
#   'Humidity': 96,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Krasnoselkup',
#   'Country': 'RU',
#   'Lat': 65.7,
#   'Lng': 82.4667,
#   'Max Temp': -0.63,
#   'Humidity': 94,
#   'Cloudiness': 35,
#   'Wind Speed': 12.08,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 86,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Zhaoyuan',
#   'Country': 'CN',
#   'Lat': 37.3592,
#   'Lng': 120.3964,
#   'Max Temp': 52.2,
#   'Humidity': 24,
#   'Cloudiness': 100,
#   'Wind Speed': 10.6,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -11.2,
#   'Humidity': 64,
#   'Cloudiness': 1,
#   'Wind Speed': 17.27,
#   'Current Description': 'clear sky'},
#  {'City': 'Rio Grande',
#   'Country': 'BR',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 61,
#   'Humidity': 98,
#   'Cloudiness': 52,
#   'Wind Speed': 7.54,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 60.62,
#   'Humidity': 83,
#   'Cloudiness': 70,
#   'Wind Speed': 24.83,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 77,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 62.11,
#   'Humidity': 95,
#   'Cloudiness': 32,
#   'Wind Speed': 2.77,
#   'Current Description': 'light rain'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 1.83,
#   'Humidity': 83,
#   'Cloudiness': 97,
#   'Wind Speed': 5.79,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -21.3,
#   'Humidity': 80,
#   'Cloudiness': 77,
#   'Wind Speed': 6.46,
#   'Current Description': 'broken clouds'},
#  {'City': 'Acarau',
#   'Country': 'BR',
#   'Lat': -2.8856,
#   'Lng': -40.12,
#   'Max Temp': 76.32,
#   'Humidity': 86,
#   'Cloudiness': 9,
#   'Wind Speed': 4.9,
#   'Current Description': 'light rain'},
#  {'City': 'Vila Franca Do Campo',
#   'Country': 'PT',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 59,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Olean',
#   'Country': 'US',
#   'Lat': 42.0776,
#   'Lng': -78.4297,
#   'Max Temp': 34,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Current Description': 'light snow'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 80.91,
#   'Humidity': 75,
#   'Cloudiness': 78,
#   'Wind Speed': 16.08,
#   'Current Description': 'broken clouds'},
#  {'City': 'Quesnel',
#   'Country': 'CA',
#   'Lat': 52.9999,
#   'Lng': -122.5029,
#   'Max Temp': 33.8,
#   'Humidity': 64,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bilibino',
#   'Country': 'RU',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -0.27,
#   'Humidity': 86,
#   'Cloudiness': 85,
#   'Wind Speed': 3.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Morant Bay',
#   'Country': 'JM',
#   'Lat': 17.8815,
#   'Lng': -76.4093,
#   'Max Temp': 80.6,
#   'Humidity': 50,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Current Description': 'few clouds'},
#  {'City': 'Deputatskiy',
#   'Country': 'RU',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': 10.89,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 3.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Naze',
#   'Country': 'JP',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 71.6,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Springdale',
#   'Country': 'US',
#   'Lat': 36.1867,
#   'Lng': -94.1288,
#   'Max Temp': 46.99,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 61,
#   'Humidity': 87,
#   'Cloudiness': 64,
#   'Wind Speed': 10,
#   'Current Description': 'broken clouds'},
#  {'City': 'Marawi',
#   'Country': 'PH',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 82.99,
#   'Humidity': 83,
#   'Cloudiness': 88,
#   'Wind Speed': 5.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 81,
#   'Humidity': 83,
#   'Cloudiness': 30,
#   'Wind Speed': 1.99,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Boda',
#   'Country': 'CF',
#   'Lat': 4.3189,
#   'Lng': 17.4695,
#   'Max Temp': 73.58,
#   'Humidity': 68,
#   'Cloudiness': 16,
#   'Wind Speed': 2.01,
#   'Current Description': 'few clouds'},
#  {'City': 'Ponta Delgada',
#   'Country': 'PT',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 59,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sinnamary',
#   'Country': 'GF',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 77.54,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 14,
#   'Current Description': 'light rain'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 64.69,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 13.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hasaki',
#   'Country': 'JP',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 70,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 73.4,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Current Description': 'few clouds'},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 68.9,
#   'Humidity': 72,
#   'Cloudiness': 32,
#   'Wind Speed': 15.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kaputa',
#   'Country': 'ZM',
#   'Lat': -8.4689,
#   'Lng': 29.6619,
#   'Max Temp': 66.6,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.86,
#   'Current Description': 'light rain'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': -24.09,
#   'Humidity': 72,
#   'Cloudiness': 19,
#   'Wind Speed': 4.79,
#   'Current Description': 'few clouds'},
#  {'City': 'Porto Santo',
#   'Country': 'PT',
#   'Lat': 33.072,
#   'Lng': -16.3415,
#   'Max Temp': 62.6,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'light rain'},
#  {'City': 'Hun',
#   'Country': 'LY',
#   'Lat': 29.1268,
#   'Lng': 15.9477,
#   'Max Temp': 53.37,
#   'Humidity': 39,
#   'Cloudiness': 18,
#   'Wind Speed': 6.31,
#   'Current Description': 'few clouds'},
#  {'City': 'Garowe',
#   'Country': 'SO',
#   'Lat': 8.4054,
#   'Lng': 48.4845,
#   'Max Temp': 70.23,
#   'Humidity': 67,
#   'Cloudiness': 99,
#   'Wind Speed': 3.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nchelenge',
#   'Country': 'ZM',
#   'Lat': -9.3451,
#   'Lng': 28.734,
#   'Max Temp': 67.46,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 5.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 25,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Udachnyy',
#   'Country': 'RU',
#   'Lat': 66.4167,
#   'Lng': 112.4,
#   'Max Temp': 21.97,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 6.08,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 63,
#   'Humidity': 41,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Current Description': 'broken clouds'},
#  {'City': 'Grindavik',
#   'Country': 'IS',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 28.4,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 3.13,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 6.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Semey',
#   'Country': 'KZ',
#   'Lat': 50.4111,
#   'Lng': 80.2275,
#   'Max Temp': 32,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 11.18,
#   'Current Description': 'light rain and snow'},
#  {'City': 'Lucea',
#   'Country': 'JM',
#   'Lat': 18.451,
#   'Lng': -78.1736,
#   'Max Temp': 77,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Current Description': 'few clouds'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 60.35,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 5.17,
#   'Current Description': 'clear sky'},
#  {'City': 'Codrington',
#   'Country': 'AU',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 63.86,
#   'Humidity': 57,
#   'Cloudiness': 39,
#   'Wind Speed': 10.04,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dukat',
#   'Country': 'RU',
#   'Lat': 62.55,
#   'Lng': 155.55,
#   'Max Temp': 9.52,
#   'Humidity': 70,
#   'Cloudiness': 81,
#   'Wind Speed': 4.16,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bowen',
#   'Country': 'AU',
#   'Lat': -20.0167,
#   'Lng': 148.2333,
#   'Max Temp': 86,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dingle',
#   'Country': 'PH',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 86.58,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 11.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shelburne',
#   'Country': 'CA',
#   'Lat': 44.0787,
#   'Lng': -80.2041,
#   'Max Temp': 35.01,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 23.96,
#   'Current Description': 'light snow'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 63,
#   'Humidity': 48,
#   'Cloudiness': 80,
#   'Wind Speed': 3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Beringovskiy',
#   'Country': 'RU',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 15.13,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 17.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mineiros',
#   'Country': 'BR',
#   'Lat': -17.5694,
#   'Lng': -52.5511,
#   'Max Temp': 67.57,
#   'Humidity': 64,
#   'Cloudiness': 4,
#   'Wind Speed': 2.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 82.94,
#   'Humidity': 72,
#   'Cloudiness': 30,
#   'Wind Speed': 21.21,
#   'Current Description': 'light rain'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.43,
#   'Humidity': 79,
#   'Cloudiness': 47,
#   'Wind Speed': 14.79,
#   'Current Description': 'light rain'},
#  {'City': 'Sambava',
#   'Country': 'MG',
#   'Lat': -14.2667,
#   'Lng': 50.1667,
#   'Max Temp': 75.33,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lawrenceburg',
#   'Country': 'US',
#   'Lat': 38.0373,
#   'Lng': -84.8966,
#   'Max Temp': 39.2,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 5.84,
#   'Current Description': 'few clouds'},
#  {'City': 'Lamar',
#   'Country': 'US',
#   'Lat': 33.6668,
#   'Lng': -95.5836,
#   'Max Temp': 55.4,
#   'Humidity': 41,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Thinadhoo',
#   'Country': 'MV',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 78.98,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 33.15,
#   'Current Description': 'moderate rain'},
#  {'City': 'General Roca',
#   'Country': 'AR',
#   'Lat': -39.0333,
#   'Lng': -67.5833,
#   'Max Temp': 51.8,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 9.35,
#   'Current Description': 'clear sky'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 23,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Current Description': 'snow'},
#  {'City': 'San Benito',
#   'Country': 'US',
#   'Lat': 36.6166,
#   'Lng': -121.0844,
#   'Max Temp': 63,
#   'Humidity': 23,
#   'Cloudiness': 1,
#   'Wind Speed': 5.06,
#   'Current Description': 'clear sky'},
#  {'City': 'Przhevalskoye',
#   'Country': 'RU',
#   'Lat': 55.5093,
#   'Lng': 31.8482,
#   'Max Temp': 34.7,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.47,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yulara',
#   'Country': 'AU',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 86,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 75.99,
#   'Humidity': 94,
#   'Cloudiness': 18,
#   'Wind Speed': 1.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 70.99,
#   'Humidity': 86,
#   'Cloudiness': 2,
#   'Wind Speed': 6.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Kungurtug',
#   'Country': 'RU',
#   'Lat': 50.5994,
#   'Lng': 97.5228,
#   'Max Temp': 28.87,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 0.14,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 11.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Broome',
#   'Country': 'US',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 41,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 23.02,
#   'Current Description': 'light rain'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 61,
#   'Humidity': 87,
#   'Cloudiness': 25,
#   'Wind Speed': 10,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bondo',
#   'Country': 'CD',
#   'Lat': 3.8146,
#   'Lng': 23.6866,
#   'Max Temp': 67.64,
#   'Humidity': 66,
#   'Cloudiness': 2,
#   'Wind Speed': 1.86,
#   'Current Description': 'clear sky'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': -9.4,
#   'Humidity': 49,
#   'Cloudiness': 15,
#   'Wind Speed': 1.14,
#   'Current Description': 'few clouds'},
#  {'City': 'Virden',
#   'Country': 'US',
#   'Lat': 39.5009,
#   'Lng': -89.7679,
#   'Max Temp': 41,
#   'Humidity': 60,
#   'Cloudiness': 27,
#   'Wind Speed': 1.99,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 75.2,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 18.41,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kimbe',
#   'Country': 'PG',
#   'Lat': -5.5502,
#   'Lng': 150.1429,
#   'Max Temp': 85.73,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 3.69,
#   'Current Description': 'light rain'},
#  {'City': 'Maragogi',
#   'Country': 'BR',
#   'Lat': -9.0122,
#   'Lng': -35.2225,
#   'Max Temp': 77.52,
#   'Humidity': 83,
#   'Cloudiness': 87,
#   'Wind Speed': 4.09,
#   'Current Description': 'light rain'},
#  {'City': 'Marsa Matruh',
#   'Country': 'EG',
#   'Lat': 31.3525,
#   'Lng': 27.2453,
#   'Max Temp': 57.2,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ballina',
#   'Country': 'AU',
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Max Temp': 80.6,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'light rain'},
#  {'City': 'Tutoia',
#   'Country': 'BR',
#   'Lat': -2.7619,
#   'Lng': -42.2744,
#   'Max Temp': 76.14,
#   'Humidity': 88,
#   'Cloudiness': 43,
#   'Wind Speed': 6.08,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Namibe',
#   'Country': 'AO',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 72.45,
#   'Humidity': 78,
#   'Cloudiness': 56,
#   'Wind Speed': 2.62,
#   'Current Description': 'light rain'},
#  {'City': 'Los Llanos De Aridane',
#   'Country': 'ES',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 62.6,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Current Description': 'few clouds'},
#  {'City': 'Adrar',
#   'Country': 'MR',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 73.58,
#   'Humidity': 10,
#   'Cloudiness': 49,
#   'Wind Speed': 1.81,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sitka',
#   'Country': 'US',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 39.2,
#   'Humidity': 38,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Alice Town',
#   'Country': 'BS',
#   'Lat': 25.7167,
#   'Lng': -79.3,
#   'Max Temp': 77.43,
#   'Humidity': 76,
#   'Cloudiness': 1,
#   'Wind Speed': 9.28,
#   'Current Description': 'clear sky'},
#  {'City': 'Cravo Norte',
#   'Country': 'CO',
#   'Lat': 6.3017,
#   'Lng': -70.2041,
#   'Max Temp': 82.4,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 4.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Praia Da Vitoria',
#   'Country': 'PT',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 60.8,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 21.05,
#   'Current Description': 'few clouds'},
#  {'City': 'Camopi',
#   'Country': 'GF',
#   'Lat': 3.1655,
#   'Lng': -52.3158,
#   'Max Temp': 71.73,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ahipara',
#   'Country': 'NZ',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 71.53,
#   'Humidity': 81,
#   'Cloudiness': 63,
#   'Wind Speed': 7.05,
#   'Current Description': 'light rain'},
#  {'City': 'Port Hedland',
#   'Country': 'AU',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 100.4,
#   'Humidity': 30,
#   'Cloudiness': 46,
#   'Wind Speed': 9.22,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Priargunsk',
#   'Country': 'RU',
#   'Lat': 50.3691,
#   'Lng': 119.1012,
#   'Max Temp': 39.49,
#   'Humidity': 44,
#   'Cloudiness': 6,
#   'Wind Speed': 16.02,
#   'Current Description': 'clear sky'},
#  {'City': 'Pangnirtung',
#   'Country': 'CA',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 1.35,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 5.03,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Constitucion',
#   'Country': 'CL',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 55.72,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Current Description': 'clear sky'},
#  {'City': 'Qaqortoq',
#   'Country': 'GL',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 19.4,
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Kaeo',
#   'Country': 'NZ',
#   'Lat': -35.1,
#   'Lng': 173.7833,
#   'Max Temp': 75,
#   'Humidity': 83,
#   'Cloudiness': 42,
#   'Wind Speed': 7,
#   'Current Description': 'light rain'},
#  {'City': 'Dongsheng',
#   'Country': 'CN',
#   'Lat': 39.8161,
#   'Lng': 109.9776,
#   'Max Temp': 43.7,
#   'Humidity': 20,
#   'Cloudiness': 99,
#   'Wind Speed': 1.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Umm Kaddadah',
#   'Country': 'SD',
#   'Lat': 13.6017,
#   'Lng': 26.6876,
#   'Max Temp': 63.84,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 18.84,
#   'Current Description': 'clear sky'},
#  {'City': 'Barinas',
#   'Country': 'VE',
#   'Lat': 8.6226,
#   'Lng': -70.2075,
#   'Max Temp': 77.77,
#   'Humidity': 68,
#   'Cloudiness': 77,
#   'Wind Speed': 5.19,
#   'Current Description': 'broken clouds'},
#  {'City': 'Olafsvik',
#   'Country': 'IS',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 29.57,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 15.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Uarini',
#   'Country': 'BR',
#   'Lat': -2.99,
#   'Lng': -65.1083,
#   'Max Temp': 73.96,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.21,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rockport',
#   'Country': 'US',
#   'Lat': 28.0206,
#   'Lng': -97.0544,
#   'Max Temp': 62.6,
#   'Humidity': 63,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 59.38,
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 17.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 30.2,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 48,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Rawson',
#   'Country': 'AR',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 59.43,
#   'Humidity': 87,
#   'Cloudiness': 22,
#   'Wind Speed': 12.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Kahului',
#   'Country': 'US',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 75.2,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 21.85,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Muros',
#   'Country': 'ES',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 50,
#   'Humidity': 78,
#   'Cloudiness': 3,
#   'Wind Speed': 7.78,
#   'Current Description': 'clear sky'},
#  {'City': 'Lyngdal',
#   'Country': 'NO',
#   'Lat': 58.1376,
#   'Lng': 7.07,
#   'Max Temp': 45,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 14.76,
#   'Current Description': 'light rain'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -6.83,
#   'Humidity': 93,
#   'Cloudiness': 89,
#   'Wind Speed': 7.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Price',
#   'Country': 'US',
#   'Lat': 39.5994,
#   'Lng': -110.8107,
#   'Max Temp': 42.8,
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Bubaque',
#   'Country': 'GW',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 75.43,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 11.97,
#   'Current Description': 'clear sky'},
#  {'City': 'Vao',
#   'Country': 'NC',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 77.81,
#   'Humidity': 80,
#   'Cloudiness': 16,
#   'Wind Speed': 13.27,
#   'Current Description': 'few clouds'},
#  {'City': 'Santa Rosa',
#   'Country': 'PH',
#   'Lat': 14.3122,
#   'Lng': 121.1114,
#   'Max Temp': 90,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Current Description': 'few clouds'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -24.66,
#   'Humidity': 99,
#   'Cloudiness': 97,
#   'Wind Speed': 7.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bandarbeyla',
#   'Country': 'SO',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 76.01,
#   'Humidity': 71,
#   'Cloudiness': 41,
#   'Wind Speed': 2.21,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ucluelet',
#   'Country': 'CA',
#   'Lat': 48.9329,
#   'Lng': -125.5528,
#   'Max Temp': 44.01,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 11.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Champerico',
#   'Country': 'GT',
#   'Lat': 14.3,
#   'Lng': -91.9167,
#   'Max Temp': 66,
#   'Humidity': 93,
#   'Cloudiness': 2,
#   'Wind Speed': 7.83,
#   'Current Description': 'clear sky'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 82.76,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 29.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Meulaboh',
#   'Country': 'ID',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 82.4,
#   'Humidity': 72,
#   'Cloudiness': 92,
#   'Wind Speed': 5.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Beian',
#   'Country': 'NO',
#   'Lat': 63.6559,
#   'Lng': 9.5683,
#   'Max Temp': 41,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Shaunavon',
#   'Country': 'CA',
#   'Lat': 49.6501,
#   'Lng': -108.4181,
#   'Max Temp': 48.2,
#   'Humidity': 31,
#   'Cloudiness': 71,
#   'Wind Speed': 17.27,
#   'Current Description': 'broken clouds'},
#  {'City': 'Colomi',
#   'Country': 'BO',
#   'Lat': -17.35,
#   'Lng': -65.8667,
#   'Max Temp': 62.6,
#   'Humidity': 51,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Harwich',
#   'Country': 'GB',
#   'Lat': 51.9419,
#   'Lng': 1.2844,
#   'Max Temp': 48,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Atasu',
#   'Country': 'KZ',
#   'Lat': 48.6814,
#   'Lng': 71.6433,
#   'Max Temp': 19.56,
#   'Humidity': 86,
#   'Cloudiness': 32,
#   'Wind Speed': 9.35,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Killybegs',
#   'Country': 'IE',
#   'Lat': 54.6333,
#   'Lng': -8.45,
#   'Max Temp': 54,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 11.99,
#   'Current Description': 'moderate rain'},
#  {'City': 'Ossora',
#   'Country': 'RU',
#   'Lat': 59.2353,
#   'Lng': 163.0719,
#   'Max Temp': 20.48,
#   'Humidity': 63,
#   'Cloudiness': 25,
#   'Wind Speed': 3.38,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Havoysund',
#   'Country': 'NO',
#   'Lat': 70.9963,
#   'Lng': 24.6622,
#   'Max Temp': 33.8,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Flinders',
#   'Country': 'AU',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 78.01,
#   'Humidity': 49,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Iskateley',
#   'Country': 'RU',
#   'Lat': 67.6803,
#   'Lng': 53.1512,
#   'Max Temp': 33.12,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 12.17,
#   'Current Description': 'light snow'},
#  {'City': 'Inirida',
#   'Country': 'CO',
#   'Lat': 3.8653,
#   'Lng': -67.9239,
#   'Max Temp': 71.94,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lere',
#   'Country': 'NG',
#   'Lat': 10.387,
#   'Lng': 8.5726,
#   'Max Temp': 71.4,
#   'Humidity': 21,
#   'Cloudiness': 7,
#   'Wind Speed': 8.1,
#   'Current Description': 'clear sky'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 61.75,
#   'Humidity': 94,
#   'Cloudiness': 2,
#   'Wind Speed': 5.17,
#   'Current Description': 'clear sky'},
#  {'City': 'Japura',
#   'Country': 'ID',
#   'Lat': -0.3167,
#   'Lng': 102.35,
#   'Max Temp': 82.72,
#   'Humidity': 78,
#   'Cloudiness': 98,
#   'Wind Speed': 4.05,
#   'Current Description': 'light rain'},
#  {'City': 'Verkhnevilyuysk',
#   'Country': 'RU',
#   'Lat': 63.4453,
#   'Lng': 120.3167,
#   'Max Temp': 28.85,
#   'Humidity': 88,
#   'Cloudiness': 85,
#   'Wind Speed': 3.83,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ambon',
#   'Country': 'ID',
#   'Lat': -3.6954,
#   'Lng': 128.1814,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Sao Joao Da Barra',
#   'Country': 'BR',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 76.59,
#   'Humidity': 89,
#   'Cloudiness': 70,
#   'Wind Speed': 5.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'La Candelaria',
#   'Country': 'VE',
#   'Lat': 9.6855,
#   'Lng': -63.4038,
#   'Max Temp': 72.95,
#   'Humidity': 87,
#   'Cloudiness': 10,
#   'Wind Speed': 6.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -0.4,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bourail',
#   'Country': 'NC',
#   'Lat': -21.5667,
#   'Lng': 165.4833,
#   'Max Temp': 85.95,
#   'Humidity': 56,
#   'Cloudiness': 3,
#   'Wind Speed': 12.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 64.99,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Current Description': 'few clouds'},
#  {'City': 'Byron Bay',
#   'Country': 'AU',
#   'Lat': -28.65,
#   'Lng': 153.6167,
#   'Max Temp': 78.01,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'light rain'},
#  {'City': 'Vuktyl',
#   'Country': 'RU',
#   'Lat': 63.8567,
#   'Lng': 57.3094,
#   'Max Temp': 26.26,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 3.09,
#   'Current Description': 'light snow'},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 68,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Current Description': 'clear sky'},
#  {'City': 'Nanfeng',
#   'Country': 'CN',
#   'Lat': 23.7434,
#   'Lng': 111.7959,
#   'Max Temp': 89.13,
#   'Humidity': 51,
#   'Cloudiness': 74,
#   'Wind Speed': 5.17,
#   'Current Description': 'broken clouds'},
#  {'City': 'Teya',
#   'Country': 'RU',
#   'Lat': 60.3778,
#   'Lng': 92.6267,
#   'Max Temp': 28.51,
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 3.47,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zhanaozen',
#   'Country': 'KZ',
#   'Lat': 43.3,
#   'Lng': 52.8,
#   'Max Temp': 38.61,
#   'Humidity': 88,
#   'Cloudiness': 88,
#   'Wind Speed': 5.86,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 68,
#   'Humidity': 60,
#   'Cloudiness': 40,
#   'Wind Speed': 6.76,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sola',
#   'Country': 'VU',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 82.89,
#   'Humidity': 75,
#   'Cloudiness': 6,
#   'Wind Speed': 15.95,
#   'Current Description': 'light rain'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 73.4,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Current Description': 'few clouds'},
#  {'City': 'Beloha',
#   'Country': 'MG',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 68.23,
#   'Humidity': 89,
#   'Cloudiness': 11,
#   'Wind Speed': 3,
#   'Current Description': 'few clouds'},
#  {'City': 'Cockburn Town',
#   'Country': 'TC',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 77.38,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 23.02,
#   'Current Description': 'clear sky'},
#  {'City': 'Polunochnoye',
#   'Country': 'RU',
#   'Lat': 60.8697,
#   'Lng': 60.4153,
#   'Max Temp': 25.11,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.33,
#   'Current Description': 'light snow'},
#  {'City': 'Caravelas',
#   'Country': 'BR',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 75.7,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 6.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Buxtehude',
#   'Country': 'DE',
#   'Lat': 53.45,
#   'Lng': 9.7,
#   'Max Temp': 50,
#   'Humidity': 71,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Antofagasta',
#   'Country': 'CL',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 60.8,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 19.4,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Pundaguitan',
#   'Country': 'PH',
#   'Lat': 6.3711,
#   'Lng': 126.1689,
#   'Max Temp': 81.61,
#   'Humidity': 78,
#   'Cloudiness': 55,
#   'Wind Speed': 3.85,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hamilton',
#   'Country': 'US',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 42.01,
#   'Humidity': 48,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Current Description': 'light rain'},
#  {'City': 'Kirovskiy',
#   'Country': 'RU',
#   'Lat': 45.0917,
#   'Lng': 133.5136,
#   'Max Temp': 37.78,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4.5,
#   'Current Description': 'light rain'},
#  {'City': 'Tautira',
#   'Country': 'PF',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 87.01,
#   'Humidity': 54,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Current Description': 'light rain'},
#  {'City': 'Lorengau',
#   'Country': 'PG',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 86.29,
#   'Humidity': 67,
#   'Cloudiness': 94,
#   'Wind Speed': 10.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Okato',
#   'Country': 'NZ',
#   'Lat': -39.2,
#   'Lng': 173.8833,
#   'Max Temp': 66.99,
#   'Humidity': 94,
#   'Cloudiness': 33,
#   'Wind Speed': 8.99,
#   'Current Description': 'light rain'},
#  {'City': 'Pokaran',
#   'Country': 'IN',
#   'Lat': 26.9167,
#   'Lng': 71.9167,
#   'Max Temp': 83.35,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 21.34,
#   'Current Description': 'clear sky'},
#  {'City': 'Si Sa Ket',
#   'Country': 'TH',
#   'Lat': 14.8333,
#   'Lng': 104.3333,
#   'Max Temp': 97,
#   'Humidity': 54,
#   'Cloudiness': 62,
#   'Wind Speed': 8.9,
#   'Current Description': 'broken clouds'},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 71.6,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lar',
#   'Country': 'IN',
#   'Lat': 26.2039,
#   'Lng': 83.9717,
#   'Max Temp': 87.46,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 6.73,
#   'Current Description': 'clear sky'},
#  {'City': 'Amara',
#   'Country': 'IQ',
#   'Lat': 31.8406,
#   'Lng': 47.1396,
#   'Max Temp': 55.15,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 15.32,
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Pierre',
#   'Country': 'RE',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 77,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Kidal',
#   'Country': 'ML',
#   'Lat': 18.4411,
#   'Lng': 1.4078,
#   'Max Temp': 68.61,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 13.15,
#   'Current Description': 'clear sky'},
#  {'City': 'Bani',
#   'Country': 'DO',
#   'Lat': 18.2833,
#   'Lng': -70.3333,
#   'Max Temp': 75,
#   'Humidity': 82,
#   'Cloudiness': 6,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 10.4,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Current Description': 'light snow'},
#  {'City': 'Dicabisagan',
#   'Country': 'PH',
#   'Lat': 17.0818,
#   'Lng': 122.4157,
#   'Max Temp': 85.96,
#   'Humidity': 63,
#   'Cloudiness': 78,
#   'Wind Speed': 5.77,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tatarskaya Pishlya',
#   'Country': 'RU',
#   'Lat': 54.0608,
#   'Lng': 44.8998,
#   'Max Temp': 22.53,
#   'Humidity': 92,
#   'Cloudiness': 95,
#   'Wind Speed': 9.13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pechenga',
#   'Country': 'RU',
#   'Lat': 69.5259,
#   'Lng': 31.1703,
#   'Max Temp': 30.2,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kormilovka',
#   'Country': 'RU',
#   'Lat': 55.0026,
#   'Lng': 74.1028,
#   'Max Temp': 21.2,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 20.13,
#   'Current Description': 'snow'},
#  {'City': 'Port-Gentil',
#   'Country': 'GA',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 77.23,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 11.59,
#   'Current Description': 'moderate rain'},
#  {'City': 'Zunyi',
#   'Country': 'CN',
#   'Lat': 27.6867,
#   'Lng': 106.9072,
#   'Max Temp': 72.63,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 5.12,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Brae',
#   'Country': 'GB',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 46.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 19.57,
#   'Current Description': 'light intensity drizzle'},
#  {'City': 'Ponnani',
#   'Country': 'IN',
#   'Lat': 10.767,
#   'Lng': 75.9252,
#   'Max Temp': 82.4,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 31.69,
#   'Humidity': 75,
#   'Cloudiness': 5,
#   'Wind Speed': 2.35,
#   'Current Description': 'clear sky'},
#  {'City': 'Ejura',
#   'Country': 'GH',
#   'Lat': 7.3856,
#   'Lng': -1.3562,
#   'Max Temp': 77.23,
#   'Humidity': 77,
#   'Cloudiness': 7,
#   'Wind Speed': 6.58,
#   'Current Description': 'clear sky'},
#  {'City': 'Cabra',
#   'Country': 'ES',
#   'Lat': 37.4725,
#   'Lng': -4.4421,
#   'Max Temp': 54,
#   'Humidity': 75,
#   'Cloudiness': 47,
#   'Wind Speed': 5.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'College',
#   'Country': 'US',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 19.99,
#   'Humidity': 49,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Progreso',
#   'Country': 'MX',
#   'Lat': 21.2833,
#   'Lng': -89.6667,
#   'Max Temp': 81,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Labuhan',
#   'Country': 'ID',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 84.85,
#   'Humidity': 70,
#   'Cloudiness': 93,
#   'Wind Speed': 2.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
# ...
#   'Max Temp': 44.6,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mocuba',
#   'Country': 'MZ',
#   'Lat': -16.8392,
#   'Lng': 36.9856,
#   'Max Temp': 68.45,
#   'Humidity': 99,
#   'Cloudiness': 89,
#   'Wind Speed': 3.65,
#   'Current Description': 'light rain'},
#  {'City': 'Kerepehi',
#   'Country': 'NZ',
#   'Lat': -37.3,
#   'Lng': 175.5333,
#   'Max Temp': 71.01,
#   'Humidity': 86,
#   'Cloudiness': 84,
#   'Wind Speed': 8.01,
#   'Current Description': 'light rain'},
#  {'City': 'Kuytun',
#   'Country': 'RU',
#   'Lat': 54.3419,
#   'Lng': 101.5036,
#   'Max Temp': 30.56,
#   'Humidity': 91,
#   'Cloudiness': 98,
#   'Wind Speed': 1.21,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Praya',
#   'Country': 'CV',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 68,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Velenje',
#   'Country': 'SI',
#   'Lat': 46.3592,
#   'Lng': 15.1103,
#   'Max Temp': 37,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Axim',
#   'Country': 'GH',
#   'Lat': 4.8699,
#   'Lng': -2.2405,
#   'Max Temp': 78.44,
#   'Humidity': 90,
#   'Cloudiness': 43,
#   'Wind Speed': 5.32,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bure',
#   'Country': 'ET',
#   'Lat': 10.7,
#   'Lng': 37.0667,
#   'Max Temp': 61.74,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 4.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Abha',
#   'Country': 'SA',
#   'Lat': 18.2164,
#   'Lng': 42.5053,
#   'Max Temp': 59,
#   'Humidity': 38,
#   'Cloudiness': 2,
#   'Wind Speed': 6.91,
#   'Current Description': 'dust'},
#  {'City': 'Mwene-Ditu',
#   'Country': 'CD',
#   'Lat': -7,
#   'Lng': 23.45,
#   'Max Temp': 64.67,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 0.4,
#   'Current Description': 'light rain'},
#  {'City': 'Porbandar',
#   'Country': 'IN',
#   'Lat': 21.6422,
#   'Lng': 69.6093,
#   'Max Temp': 79.47,
#   'Humidity': 59,
#   'Cloudiness': 9,
#   'Wind Speed': 3.24,
#   'Current Description': 'clear sky'},
#  {'City': 'Sechura',
#   'Country': 'PE',
#   'Lat': -5.5569,
#   'Lng': -80.8222,
#   'Max Temp': 74.37,
#   'Humidity': 66,
#   'Cloudiness': 84,
#   'Wind Speed': 12.53,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kaz',
#   'Country': 'RU',
#   'Lat': 52.9113,
#   'Lng': 87.3105,
#   'Max Temp': 33.33,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 8.72,
#   'Current Description': 'snow'},
#  {'City': 'Nurota',
#   'Country': 'UZ',
#   'Lat': 40.5614,
#   'Lng': 65.6886,
#   'Max Temp': 42.8,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Current Description': 'mist'},
#  {'City': 'Whitehorse',
#   'Country': 'CA',
#   'Lat': 60.7161,
#   'Lng': -135.0538,
#   'Max Temp': 21.2,
#   'Humidity': 27,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Current Description': 'few clouds'},
#  {'City': 'Dubbo',
#   'Country': 'AU',
#   'Lat': -32.25,
#   'Lng': 148.6167,
#   'Max Temp': 73.4,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Tura',
#   'Country': 'IN',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 86.52,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 5.79,
#   'Current Description': 'clear sky'},
#  {'City': 'Moa',
#   'Country': 'CU',
#   'Lat': 20.6569,
#   'Lng': -74.9403,
#   'Max Temp': 75.92,
#   'Humidity': 82,
#   'Cloudiness': 17,
#   'Wind Speed': 12.66,
#   'Current Description': 'few clouds'},
#  {'City': 'Darhan',
#   'Country': 'MN',
#   'Lat': 49.4867,
#   'Lng': 105.9228,
#   'Max Temp': 41.54,
#   'Humidity': 23,
#   'Cloudiness': 100,
#   'Wind Speed': 5.48,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Buala',
#   'Country': 'SB',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 85.89,
#   'Humidity': 65,
#   'Cloudiness': 37,
#   'Wind Speed': 6.69,
#   'Current Description': 'scattered clouds'},
#  {'City': 'At-Bashi',
#   'Country': 'KG',
#   'Lat': 41.1702,
#   'Lng': 75.8106,
#   'Max Temp': 36.34,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 8.46,
#   'Current Description': 'light snow'},
#  {'City': 'Juba',
#   'Country': 'SS',
#   'Lat': 4.8517,
#   'Lng': 31.5825,
#   'Max Temp': 77.22,
#   'Humidity': 55,
#   'Cloudiness': 54,
#   'Wind Speed': 2.73,
#   'Current Description': 'broken clouds'},
#  {'City': 'Castlecomer',
#   'Country': 'IE',
#   'Lat': 52.8061,
#   'Lng': -7.2106,
#   'Max Temp': 55,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Griffith',
#   'Country': 'US',
#   'Lat': 41.5284,
#   'Lng': -87.4237,
#   'Max Temp': 39,
#   'Humidity': 52,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Nizwa',
#   'Country': 'OM',
#   'Lat': 22.9333,
#   'Lng': 57.5333,
#   'Max Temp': 82.17,
#   'Humidity': 14,
#   'Cloudiness': 44,
#   'Wind Speed': 4.32,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dodge City',
#   'Country': 'US',
#   'Lat': 37.7528,
#   'Lng': -100.0171,
#   'Max Temp': 57,
#   'Humidity': 50,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Metro',
#   'Country': 'ID',
#   'Lat': -5.1131,
#   'Lng': 105.3067,
#   'Max Temp': 85.15,
#   'Humidity': 70,
#   'Cloudiness': 67,
#   'Wind Speed': 1.48,
#   'Current Description': 'light rain'},
#  {'City': 'Mastic Beach',
#   'Country': 'US',
#   'Lat': 40.7668,
#   'Lng': -72.8521,
#   'Max Temp': 55.4,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'moderate rain'},
#  {'City': 'La Ronge',
#   'Country': 'CA',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 35.6,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Oyama',
#   'Country': 'JP',
#   'Lat': 36.3,
#   'Lng': 139.8,
#   'Max Temp': 75,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Oromocto',
#   'Country': 'CA',
#   'Lat': 45.8351,
#   'Lng': -66.4792,
#   'Max Temp': 33.8,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Current Description': 'moderate rain'},
#  {'City': 'Hays',
#   'Country': 'US',
#   'Lat': 30.0502,
#   'Lng': -98.0336,
#   'Max Temp': 59,
#   'Humidity': 56,
#   'Cloudiness': 7,
#   'Wind Speed': 5.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Desdunes',
#   'Country': 'HT',
#   'Lat': 19.2955,
#   'Lng': -72.646,
#   'Max Temp': 76.8,
#   'Humidity': 77,
#   'Cloudiness': 3,
#   'Wind Speed': 5.86,
#   'Current Description': 'clear sky'},
#  {'City': 'Kuala Terengganu',
#   'Country': 'MY',
#   'Lat': 5.3302,
#   'Lng': 103.1408,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Nerchinskiy Zavod',
#   'Country': 'RU',
#   'Lat': 51.3088,
#   'Lng': 119.61,
#   'Max Temp': 32.52,
#   'Humidity': 76,
#   'Cloudiness': 33,
#   'Wind Speed': 11.18,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Yarada',
#   'Country': 'IN',
#   'Lat': 17.65,
#   'Lng': 83.2667,
#   'Max Temp': 83.89,
#   'Humidity': 67,
#   'Cloudiness': 4,
#   'Wind Speed': 9.28,
#   'Current Description': 'clear sky'},
#  {'City': 'Biak',
#   'Country': 'ID',
#   'Lat': -0.9131,
#   'Lng': 122.8766,
#   'Max Temp': 81.23,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 0.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Uray',
#   'Country': 'RU',
#   'Lat': 60.1247,
#   'Lng': 64.7758,
#   'Max Temp': 13.86,
#   'Humidity': 94,
#   'Cloudiness': 74,
#   'Wind Speed': 7.16,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lubango',
#   'Country': 'AO',
#   'Lat': -14.9172,
#   'Lng': 13.4925,
#   'Max Temp': 59.23,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Laguna',
#   'Country': 'US',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 71.6,
#   'Humidity': 30,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Tungor',
#   'Country': 'RU',
#   'Lat': 53.3808,
#   'Lng': 142.9564,
#   'Max Temp': 31.39,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 12.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Longhua',
#   'Country': 'CN',
#   'Lat': 23.6137,
#   'Lng': 114.1919,
#   'Max Temp': 88.68,
#   'Humidity': 50,
#   'Cloudiness': 83,
#   'Wind Speed': 6.51,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mayo',
#   'Country': 'US',
#   'Lat': 38.8876,
#   'Lng': -76.5119,
#   'Max Temp': 55.4,
#   'Humidity': 44,
#   'Cloudiness': 20,
#   'Wind Speed': 19.57,
#   'Current Description': 'few clouds'},
#  {'City': 'Vestmanna',
#   'Country': 'FO',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp': 37.4,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Current Description': 'light rain'},
#  {'City': 'Inhambane',
#   'Country': 'MZ',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 73.17,
#   'Humidity': 73,
#   'Cloudiness': 23,
#   'Wind Speed': 12.26,
#   'Current Description': 'light rain'},
#  {'City': 'Tooele',
#   'Country': 'US',
#   'Lat': 40.5308,
#   'Lng': -112.2983,
#   'Max Temp': 53.01,
#   'Humidity': 43,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Oranjestad',
#   'Country': 'AW',
#   'Lat': 12.524,
#   'Lng': -70.027,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 19.57,
#   'Current Description': 'few clouds'},
#  {'City': 'Staryy Nadym',
#   'Country': 'RU',
#   'Lat': 65.6118,
#   'Lng': 72.6842,
#   'Max Temp': -7.55,
#   'Humidity': 96,
#   'Cloudiness': 28,
#   'Wind Speed': 9.62,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kumluca',
#   'Country': 'TR',
#   'Lat': 36.3703,
#   'Lng': 30.2869,
#   'Max Temp': 53.51,
#   'Humidity': 50,
#   'Cloudiness': 5,
#   'Wind Speed': 4.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Duluth',
#   'Country': 'US',
#   'Lat': 46.7833,
#   'Lng': -92.1066,
#   'Max Temp': 35.6,
#   'Humidity': 51,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Carutapera',
#   'Country': 'BR',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 75.13,
#   'Humidity': 94,
#   'Cloudiness': 60,
#   'Wind Speed': 5.39,
#   'Current Description': 'light rain'},
#  {'City': 'Gewane',
#   'Country': 'ET',
#   'Lat': 10.1664,
#   'Lng': 40.6453,
#   'Max Temp': 73.81,
#   'Humidity': 34,
#   'Cloudiness': 83,
#   'Wind Speed': 2.89,
#   'Current Description': 'broken clouds'},
#  {'City': 'Shimanovsk',
#   'Country': 'RU',
#   'Lat': 52,
#   'Lng': 127.7,
#   'Max Temp': 33.31,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 7.07,
#   'Current Description': 'light snow'},
#  {'City': 'Kasongo-Lunda',
#   'Country': 'CD',
#   'Lat': -6.4667,
#   'Lng': 16.8167,
#   'Max Temp': 69.31,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 0.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Santa Marta',
#   'Country': 'CO',
#   'Lat': 11.2408,
#   'Lng': -74.199,
#   'Max Temp': 84,
#   'Humidity': 69,
#   'Cloudiness': 58,
#   'Wind Speed': 14.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bartica',
#   'Country': 'GY',
#   'Lat': 6.4,
#   'Lng': -58.6167,
#   'Max Temp': 75.2,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'light rain'},
#  {'City': 'Floro',
#   'Country': 'NO',
#   'Lat': 61.5996,
#   'Lng': 5.0328,
#   'Max Temp': 39.2,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 19.57,
#   'Current Description': 'light rain'},
#  {'City': 'Bodden Town',
#   'Country': 'KY',
#   'Lat': 19.2833,
#   'Lng': -81.25,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Current Description': 'few clouds'},
#  {'City': 'Hambantota',
#   'Country': 'LK',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Atbasar',
#   'Country': 'KZ',
#   'Lat': 51.8,
#   'Lng': 68.3333,
#   'Max Temp': 17.98,
#   'Humidity': 94,
#   'Cloudiness': 48,
#   'Wind Speed': 12.33,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bulawayo',
#   'Country': 'ZW',
#   'Lat': -20.15,
#   'Lng': 28.5833,
#   'Max Temp': 56.68,
#   'Humidity': 92,
#   'Cloudiness': 4,
#   'Wind Speed': 13.71,
#   'Current Description': 'clear sky'},
#  {'City': 'Maniitsoq',
#   'Country': 'GL',
#   'Lat': 65.4167,
#   'Lng': -52.9,
#   'Max Temp': 1.51,
#   'Humidity': 62,
#   'Cloudiness': 48,
#   'Wind Speed': 9.64,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mobara',
#   'Country': 'JP',
#   'Lat': 35.4167,
#   'Lng': 140.3,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bud',
#   'Country': 'US',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 37.99,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 7.38,
#   'Current Description': 'clear sky'},
#  {'City': 'Broken Hill',
#   'Country': 'AU',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 71.6,
#   'Humidity': 37,
#   'Cloudiness': 3,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Havre-Saint-Pierre',
#   'Country': 'CA',
#   'Lat': 50.2334,
#   'Lng': -63.5986,
#   'Max Temp': 26.6,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Current Description': 'snow'},
#  {'City': 'Rajgarh',
#   'Country': 'IN',
#   'Lat': 28.6333,
#   'Lng': 75.3833,
#   'Max Temp': 86.86,
#   'Humidity': 16,
#   'Cloudiness': 43,
#   'Wind Speed': 16.64,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Altay',
#   'Country': 'CN',
#   'Lat': 47.8667,
#   'Lng': 88.1167,
#   'Max Temp': 37.69,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 4.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shimoda',
#   'Country': 'JP',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 69.01,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jalostotitlan',
#   'Country': 'MX',
#   'Lat': 21.2,
#   'Lng': -102.4667,
#   'Max Temp': 69.8,
#   'Humidity': 40,
#   'Cloudiness': 1,
#   'Wind Speed': 12.66,
#   'Current Description': 'clear sky'},
#  {'City': 'Matagami',
#   'Country': 'CA',
#   'Lat': 49.7502,
#   'Lng': -77.6328,
#   'Max Temp': 17.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 29.93,
#   'Current Description': 'light snow'},
#  {'City': 'Kizukuri',
#   'Country': 'JP',
#   'Lat': 40.8061,
#   'Lng': 140.3861,
#   'Max Temp': 60.8,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 18.41,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Aasiaat',
#   'Country': 'GL',
#   'Lat': 68.7098,
#   'Lng': -52.8699,
#   'Max Temp': -21.66,
#   'Humidity': 84,
#   'Cloudiness': 46,
#   'Wind Speed': 10.04,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lom Sak',
#   'Country': 'TH',
#   'Lat': 16.7798,
#   'Lng': 101.2422,
#   'Max Temp': 87.8,
#   'Humidity': 58,
#   'Cloudiness': 78,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Caxito',
#   'Country': 'AO',
#   'Lat': -8.5785,
#   'Lng': 13.6643,
#   'Max Temp': 78.8,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Jian',
#   'Country': 'CN',
#   'Lat': 27.1172,
#   'Lng': 114.9793,
#   'Max Temp': 82.06,
#   'Humidity': 58,
#   'Cloudiness': 18,
#   'Wind Speed': 5.88,
#   'Current Description': 'few clouds'},
#  {'City': 'Tongliao',
#   'Country': 'CN',
#   'Lat': 43.6125,
#   'Lng': 122.2653,
#   'Max Temp': 50.05,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 21.83,
#   'Current Description': 'clear sky'},
#  {'City': 'Rodbyhavn',
#   'Country': 'DK',
#   'Lat': 54.6544,
#   'Lng': 11.352,
#   'Max Temp': 48,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fort Wellington',
#   'Country': 'GY',
#   'Lat': 6.4,
#   'Lng': -57.6,
#   'Max Temp': 76.51,
#   'Humidity': 89,
#   'Cloudiness': 89,
#   'Wind Speed': 11.97,
#   'Current Description': 'light rain'},
#  {'City': 'Sibiti',
#   'Country': 'CG',
#   'Lat': -3.6819,
#   'Lng': 13.3499,
#   'Max Temp': 69.01,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Current Description': 'light rain'},
#  {'City': 'Morden',
#   'Country': 'CA',
#   'Lat': 49.1919,
#   'Lng': -98.1014,
#   'Max Temp': 39.2,
#   'Humidity': 38,
#   'Cloudiness': 60,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'}]

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Hualmay      PE -11.0964  -77.6139     69.87        82
# 1         Chokurdakh      RU  70.6333  147.9167      3.36        93
# 2            Xinqing      CN  48.2333  129.5000     36.27        98
# 3              Vardo      NO  70.3705   31.1107     33.80        86
# 4            Rikitea      PF -23.1203 -134.9692     79.72        71
# ..               ...     ...      ...       ...       ...       ...
# 713         Tongliao      CN  43.6125  122.2653     50.05        25
# 714        Rodbyhavn      DK  54.6544   11.3520     48.00        89
# 715  Fort Wellington      GY   6.4000  -57.6000     76.51        89
# 716           Sibiti      CG  -3.6819   13.3499     69.01        99
# 717           Morden      CA  49.1919  -98.1014     39.20        38
#
#      Cloudiness  Wind Speed Current Description
# 0            75        5.95       broken clouds
# 1            97        5.19     overcast clouds
# 2           100        2.84          light snow
# 3            75        9.22       broken clouds
# 4             1       14.63           clear sky
# ..          ...         ...                 ...
# 713           0       21.83           clear sky
# 714         100        3.00     overcast clouds
# 715          89       11.97          light rain
# 716         100        0.89          light rain
# 717          60       10.36       broken clouds
#
# [718 rows x 9 columns]

# %%
city_data_df.to_csv("weather_database/WeatherPy_Database.csv", index_label="City_ID")

# %%
city_
